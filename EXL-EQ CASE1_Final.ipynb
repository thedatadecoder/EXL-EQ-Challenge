# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
File = pd.ExcelFile("C:\Users\welcome\Desktop\EXL CASES\CASE 1\Data.xlsx")

# %%
File.sheet_names
# Out:
# [u'Demographics',
#  u'Store Mapping',
#  u'Category Mapping',
#  u'Ping_Information',
#  u'Variable Descriptions']

# %%
demographics= pd.read_excel(File, "Demographics")

# %%
demographics.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
demographics.head()
# Out:
#   Shopper_Id                                    ID  Age Gender Marital_Status  \
# 0  Shopper_1  831b9564-99d7-3b57-a9c0-3ac1f31560d5   23      F              D
# 1  Shopper_2  1bd5093b-5a76-3ccc-b0d2-37695a858a95   42      F              M
# 2  Shopper_3  d08139f8-c50d-3472-adf8-6dcc4724164c   51      F              M
# 3  Shopper_4  29b285af-f631-3100-9a4e-5de09df7f974   35      F              D
# 4  Shopper_5  63fc3248-9900-3074-b887-c6ed6d73d0e3   42      M              S
#
#   Owns_Home  Number_of_Children_under_18_years_of_age
# 0         N                                         1
# 1         N                                         1
# 2         N                                         1
# 3         N                                         2
# 4         N                                         0

# %%
storemapping = pd.read_excel(File, "Store Mapping")
storemapping.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
storemapping.head()
# Out:
#                            Store_Name       Floor_name  Floor_Index  \
# 0                         Jamba Juice  Concourse Level            0
# 1              Coriander Gourmet Thai  Concourse Level            0
# 2                      NYS Collection  Concourse Level            0
# 3                            Hallmark  Concourse Level            0
# 4  Sorabol Korean BBQ & Asian Noodles  Concourse Level            0
#
#     latitude   longitude
# 0  37.784091 -122.406813
# 1  37.784596 -122.406210
# 2  37.784396 -122.406587
# 3  37.783771 -122.407377
# 4  37.784601 -122.406328

# %%
categorymapping = pd.read_excel(File, "Category Mapping")
categorymapping.drop(['Unnamed: 0'], axis=1, inplace=True)
categorymapping.head()
# Out:
#           Store_Name Broad_Category    Fine_Category
# 0      Amazon Pop-Up         Retail            Misc.
# 1     Bespoke Events         Retail            Misc.
# 2  Bespoke Coworking         Retail  Specialty Store
# 3              Dyson         Retail            Misc.
# 4   Penhaligonï¿½Ûªs         Retail            Misc.

# %%
pinginformation = pd.read_excel(File, "Ping_Information")
pinginformation.drop(['Unnamed: 0'], axis=1, inplace=True)
pinginformation.head()
# Out:
#     Shopper_ID      floor        lat         lng            x             y  \
# 0  Shopper_556    Floor 4  37.661463 -122.298673 -2934.558251 -16169.722290
# 1  Shopper_556    Floor 1  37.784062 -122.406943   117.262475    151.823812
# 2  Shopper_556    Floor 4  37.784361 -122.406710   156.125087    171.357200
# 3  Shopper_360  Concourse  37.784341 -122.406891   134.499673    167.674401
# 4  Shopper_360    Floor 2  37.784017 -122.407307    94.981693    172.269243
#
#               seenTimestamp
# 0  2016-11-22T02:16:06.000Z
# 1  2016-12-23T22:01:25.000Z
# 2  2016-11-22T01:42:28.000Z
# 3  2016-10-13T18:27:38.000Z
# 4  2016-10-12T21:36:18.000Z

# %%
demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 7 columns):
# Shopper_Id                                  567 non-null object
# ID                                          567 non-null object
# Age                                         567 non-null int64
# Gender                                      567 non-null object
# Marital_Status                              567 non-null object
# Owns_Home                                   567 non-null object
# Number_of_Children_under_18_years_of_age    567 non-null int64
# dtypes: int64(2), object(5)
# memory usage: 31.1+ KB

# %%
storemapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 5 columns):
# Store_Name     166 non-null object
# Floor_name     166 non-null object
# Floor_Index    166 non-null int64
# latitude       166 non-null float64
# longitude      166 non-null float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 6.6+ KB

# %%
categorymapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 3 columns):
# Store_Name        154 non-null object
# Broad_Category    154 non-null object
# Fine_Category     154 non-null object
# dtypes: object(3)
# memory usage: 3.7+ KB

# %%
pinginformation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107635 entries, 0 to 107634
# Data columns (total 7 columns):
# Shopper_ID       107635 non-null object
# floor            107635 non-null object
# lat              107635 non-null float64
# lng              107635 non-null float64
# x                107635 non-null float64
# y                107635 non-null float64
# seenTimestamp    107635 non-null object
# dtypes: float64(4), object(3)
# memory usage: 5.7+ MB

# %%
pinginfo=pinginformation.drop(['x', 'y', 'seenTimestamp'], axis=1)

# %%
pinginfo.head()
# Out:
#     Shopper_ID      floor        lat         lng
# 0  Shopper_556    Floor 4  37.661463 -122.298673
# 1  Shopper_556    Floor 1  37.784062 -122.406943
# 2  Shopper_556    Floor 4  37.784361 -122.406710
# 3  Shopper_360  Concourse  37.784341 -122.406891
# 4  Shopper_360    Floor 2  37.784017 -122.407307

# %%
storemap = storemapping.drop(['Floor_name'], axis=1)
storemap.head()
# Out:
#                            Store_Name  Floor_Index   latitude   longitude
# 0                         Jamba Juice            0  37.784091 -122.406813
# 1              Coriander Gourmet Thai            0  37.784596 -122.406210
# 2                      NYS Collection            0  37.784396 -122.406587
# 3                            Hallmark            0  37.783771 -122.407377
# 4  Sorabol Korean BBQ & Asian Noodles            0  37.784601 -122.406328

# %%
#converting floor in pinginfo into int type:
floors= sorted(pinginfo['floor'].unique())
floors
# Out:
# [u'Concourse', u'Floor 1', u'Floor 2', u'Floor 3', u'Floor 4']

# %%
floor_mapping = dict(zip(floors, range(0, len(floors) + 1)))
floor_mapping
# Out:
# {u'Concourse': 0, u'Floor 1': 1, u'Floor 2': 2, u'Floor 3': 3, u'Floor 4': 4}

# %%
pinginfo['Floor_Index'] = pinginfo['floor'].map(floor_mapping).astype(int)
pinginfo.head()
# Out:
#     Shopper_ID      floor        lat         lng  Floor_Index
# 0  Shopper_556    Floor 4  37.661463 -122.298673            4
# 1  Shopper_556    Floor 1  37.784062 -122.406943            1
# 2  Shopper_556    Floor 4  37.784361 -122.406710            4
# 3  Shopper_360  Concourse  37.784341 -122.406891            0
# 4  Shopper_360    Floor 2  37.784017 -122.407307            2

# %%
pinginfo.drop(['floor'], axis=1, inplace=True)
pinginfo.head()
# Out:
#     Shopper_ID        lat         lng  Floor_Index
# 0  Shopper_556  37.661463 -122.298673            4
# 1  Shopper_556  37.784062 -122.406943            1
# 2  Shopper_556  37.784361 -122.406710            4
# 3  Shopper_360  37.784341 -122.406891            0
# 4  Shopper_360  37.784017 -122.407307            2

# %%
pinginfo['latitude'] = pinginfo['lat']
pinginfo['longitude'] = pinginfo['lng']

# %%
pinginfo.drop(['lat', 'lng'], axis=1, inplace=True)
pinginfo.head()
# Out:
#     Shopper_ID  Floor_Index   latitude   longitude
# 0  Shopper_556            4  37.661463 -122.298673
# 1  Shopper_556            1  37.784062 -122.406943
# 2  Shopper_556            4  37.784361 -122.406710
# 3  Shopper_360            0  37.784341 -122.406891
# 4  Shopper_360            2  37.784017 -122.407307

# %%
storemap.head()
# Out:
#                            Store_Name  Floor_Index   latitude   longitude
# 0                         Jamba Juice            0  37.784091 -122.406813
# 1              Coriander Gourmet Thai            0  37.784596 -122.406210
# 2                      NYS Collection            0  37.784396 -122.406587
# 3                            Hallmark            0  37.783771 -122.407377
# 4  Sorabol Korean BBQ & Asian Noodles            0  37.784601 -122.406328

# %%
X = storemap.drop(['Store_Name'],axis=1).as_matrix().astype(np.float)
X
# Out:
# array([[   0.      ,   37.784091, -122.406813],
#        [   0.      ,   37.784596, -122.40621 ],
#        [   0.      ,   37.784396, -122.406587],
#        [   0.      ,   37.783771, -122.407377],
#        [   0.      ,   37.784601, -122.406328],
#        [   0.      ,   37.784534, -122.406025],
#        [   0.      ,   37.783944, -122.407537],
#        [   0.      ,   37.784447, -122.406224],
#        [   0.      ,   37.784161, -122.4069  ],
#        [   0.      ,   37.784808, -122.406501],
#        [   0.      ,   37.784569, -122.406141],
#        [   0.      ,   37.78467 , -122.406679],
#        [   0.      ,   37.784126, -122.407061],
#        [   0.      ,   37.784159, -122.40635 ],
#        [   0.      ,   37.783959, -122.40691 ],
#        [   0.      ,   37.784411, -122.406709],
#        [   0.      ,   37.784511, -122.405956],
#        [   0.      ,   37.784071, -122.406885],
#        [   0.      ,   37.784591, -122.406782],
#        [   0.      ,   37.783778, -122.407161],
#        [   0.      ,   37.784053, -122.407307],
#        [   0.      ,   37.783893, -122.407389],
#        [   0.      ,   37.784222, -122.406978],
#        [   0.      ,   37.783953, -122.407318],
#        [   0.      ,   37.784505, -122.406555],
#        [   0.      ,   37.783767, -122.40707 ],
#        [   0.      ,   37.784106, -122.407189],
#        [   0.      ,   37.784292, -122.40601 ],
#        [   0.      ,   37.784449, -122.406665],
#        [   0.      ,   37.784353, -122.406773],
#        [   0.      ,   37.784294, -122.406164],
#        [   0.      ,   37.78432 , -122.406195],
#        [   0.      ,   37.783944, -122.407175],
#        [   0.      ,   37.783831, -122.406941],
#        [   0.      ,   37.784312, -122.405822],
#        [   0.      ,   37.783887, -122.405783],
#        [   0.      ,   37.784208, -122.40743 ],
#        [   0.      ,   37.784505, -122.406399],
#        [   0.      ,   37.784625, -122.406417],
#        [   0.      ,   37.784123, -122.40695 ],
#        [   0.      ,   37.78413 , -122.407374],
#        [   0.      ,   37.784037, -122.406937],
#        [   0.      ,   37.784457, -122.406819],
#        [   0.      ,   37.784415, -122.405846],
#        [   0.      ,   37.784116, -122.407124],
#        [   0.      ,   37.784157, -122.405925],
#        [   0.      ,   37.784094, -122.407625],
#        [   0.      ,   37.783791, -122.406984],
#        [   1.      ,   37.78379 , -122.40747 ],
#        [   1.      ,   37.784615, -122.406332],
#        [   1.      ,   37.78402 , -122.405965],
#        [   1.      ,   37.784179, -122.406865],
#        [   1.      ,   37.784142, -122.40704 ],
#        [   1.      ,   37.784453, -122.406443],
#        [   1.      ,   37.784033, -122.406896],
#        [   1.      ,   37.784267, -122.406579],
#        [   1.      ,   37.784296, -122.406519],
#        [   1.      ,   37.784464, -122.406181],
#        [   1.      ,   37.784195, -122.40696 ],
#        [   1.      ,   37.784221, -122.406652],
#        [   1.      ,   37.784776, -122.406643],
#        [   1.      ,   37.784527, -122.406296],
#        [   1.      ,   37.78367 , -122.407313],
#        [   1.      ,   37.783731, -122.407122],
#        [   1.      ,   37.783976, -122.406906],
#        [   1.      ,   37.784613, -122.406467],
#        [   1.      ,   37.78398 , -122.407454],
#        [   1.      ,   37.784714, -122.406476],
#        [   1.      ,   37.78409 , -122.406835],
#        [   1.      ,   37.784503, -122.406813],
#        [   1.      ,   37.784112, -122.406949],
#        [   1.      ,   37.784884, -122.406486],
#        [   1.      ,   37.78461 , -122.406886],
#        [   1.      ,   37.784466, -122.406961],
#        [   1.      ,   37.78447 , -122.40676 ],
#        [   1.      ,   37.78373 , -122.407061],
#        [   1.      ,   37.783909, -122.407393],
#        [   1.      ,   37.78381 , -122.407336],
#        [   1.      ,   37.783864, -122.406836],
#        [   1.      ,   37.784188, -122.407159],
#        [   1.      ,   37.783827, -122.407024],
#        [   1.      ,   37.784047, -122.407035],
#        [   1.      ,   37.784397, -122.406148],
#        [   1.      ,   37.784185, -122.406379],
#        [   1.      ,   37.784396, -122.406726],
#        [   2.      ,   37.784579, -122.406476],
#        [   2.      ,   37.783744, -122.407323],
#        [   2.      ,   37.784515, -122.406218],
#        [   2.      ,   37.784024, -122.407272],
#        [   2.      ,   37.784139, -122.407183],
#        [   2.      ,   37.784341, -122.406785],
#        [   2.      ,   37.784559, -122.40627 ],
#        [   2.      ,   37.784136, -122.405805],
#        [   2.      ,   37.784705, -122.406568],
#        [   2.      ,   37.784142, -122.40742 ],
#        [   2.      ,   37.784267, -122.406528],
#        [   2.      ,   37.784046, -122.406884],
#        [   2.      ,   37.784252, -122.406942],
#        [   2.      ,   37.784387, -122.406732],
#        [   2.      ,   37.783739, -122.407271],
#        [   2.      ,   37.783745, -122.407149],
#        [   2.      ,   37.784385, -122.406276],
#        [   2.      ,   37.784195, -122.407081],
#        [   2.      ,   37.784433, -122.40608 ],
#        [   2.      ,   37.784031, -122.406181],
#        [   2.      ,   37.783852, -122.405805],
#        [   2.      ,   37.783931, -122.406086],
#        [   2.      ,   37.784484, -122.406502],
#        [   2.      ,   37.783724, -122.406893],
#        [   2.      ,   37.784555, -122.406814],
#        [   2.      ,   37.783832, -122.407021],
#        [   2.      ,   37.783954, -122.407507],
#        [   2.      ,   37.784185, -122.406432],
#        [   2.      ,   37.783864, -122.406924],
#        [   2.      ,   37.783946, -122.406796],
#        [   2.      ,   37.784316, -122.40656 ],
#        [   2.      ,   37.784172, -122.406733],
#        [   2.      ,   37.784271, -122.406619],
#        [   2.      ,   37.784286, -122.406001],
#        [   3.      ,   37.784042, -122.406901],
#        [   3.      ,   37.783629, -122.407154],
#        [   3.      ,   37.783741, -122.406902],
#        [   3.      ,   37.784628, -122.406187],
#        [   3.      ,   37.78435 , -122.406064],
#        [   3.      ,   37.784105, -122.406326],
#        [   3.      ,   37.784615, -122.406862],
#        [   3.      ,   37.784428, -122.406643],
#        [   3.      ,   37.784447, -122.406809],
#        [   3.      ,   37.783986, -122.406922],
#        [   3.      ,   37.783839, -122.406836],
#        [   3.      ,   37.783812, -122.406021],
#        [   3.      ,   37.784133, -122.407419],
#        [   3.      ,   37.783752, -122.407371],
#        [   3.      ,   37.78429 , -122.406561],
#        [   3.      ,   37.783737, -122.407253],
#        [   3.      ,   37.78424 , -122.406455],
#        [   3.      ,   37.784101, -122.406854],
#        [   3.      ,   37.783871, -122.407073],
#        [   3.      ,   37.784153, -122.405871],
#        [   3.      ,   37.783745, -122.405601],
#        [   3.      ,   37.784191, -122.407111],
#        [   3.      ,   37.784267, -122.405933],
#        [   3.      ,   37.784386, -122.406589],
#        [   3.      ,   37.78454 , -122.406132],
#        [   3.      ,   37.783912, -122.407474],
#        [   3.      ,   37.784663, -122.406313],
#        [   3.      ,   37.784135, -122.406406],
#        [   3.      ,   37.783957, -122.406249],
#        [   3.      ,   37.783814, -122.407399],
#        [   3.      ,   37.784197, -122.40698 ],
#        [   3.      ,   37.784701, -122.406758],
#        [   3.      ,   37.78436 , -122.406786],
#        [   4.      ,   37.78442 , -122.406832],
#        [   4.      ,   37.784702, -122.406248],
#        [   4.      ,   37.784206, -122.406528],
#        [   4.      ,   37.784178, -122.405776],
#        [   4.      ,   37.783859, -122.40635 ],
#        [   4.      ,   37.784539, -122.406081],
#        [   4.      ,   37.78382 , -122.407311],
#        [   4.      ,   37.783802, -122.405736],
#        [   5.      ,   37.784076, -122.407307],
#        [   5.      ,   37.78389 , -122.405736],
#        [   5.      ,   37.784204, -122.406574],
#        [   6.      ,   37.78409 , -122.407309],
#        [   7.      ,   37.784073, -122.407289],
#        [   8.      ,   37.784087, -122.407307]])

# %%
#convert into matrix having mean= 0 and std dev= 1
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[-1.08827864e+00, -3.44149111e-01, -2.21927721e-01],
#        [-1.08827864e+00,  1.40158609e+00,  1.04342435e+00],
#        [-1.08827864e+00,  7.10205813e-01,  2.52317003e-01],
#        [-1.08827864e+00, -1.45035756e+00, -1.40544110e+00],
#        [-1.08827864e+00,  1.41887060e+00,  7.95809851e-01],
#        [-1.08827864e+00,  1.18725820e+00,  1.43163353e+00],
#        [-1.08827864e+00, -8.52313615e-01, -1.74118958e+00],
#        [-1.08827864e+00,  8.86507784e-01,  1.01404636e+00],
#        [-1.08827864e+00, -1.02166013e-01, -4.04490955e-01],
#        [-1.08827864e+00,  2.13444919e+00,  4.32781810e-01],
#        [-1.08827864e+00,  1.30824975e+00,  1.18821588e+00],
#        [-1.08827864e+00,  1.65739679e+00,  5.92616288e-02],
#        [-1.08827864e+00, -2.23157562e-01, -7.42337861e-01],
#        [-1.08827864e+00, -1.09079816e-01,  7.49644435e-01],
#        [-1.08827864e+00, -8.00460094e-01, -4.25475235e-01],
#        [-1.08827864e+00,  7.62059334e-01, -3.69121068e-03],
#        [-1.08827864e+00,  1.10774947e+00,  1.57642506e+00],
#        [-1.08827864e+00, -4.13287138e-01, -3.73014536e-01],
#        [-1.08827864e+00,  1.38430158e+00, -1.56876453e-01],
#        [-1.08827864e+00, -1.42615925e+00, -9.52180659e-01],
#        [-1.08827864e+00, -4.75511363e-01, -1.25855114e+00],
#        [-1.08827864e+00, -1.02861559e+00, -1.43062224e+00],
#        [-1.08827864e+00,  1.08704971e-01, -5.68168338e-01],
#        [-1.08827864e+00, -8.21201502e-01, -1.28163385e+00],
#        [-1.08827864e+00,  1.08700806e+00,  3.19466699e-01],
#        [-1.08827864e+00, -1.46418516e+00, -7.61223712e-01],
#        [-1.08827864e+00, -2.92295590e-01, -1.01093664e+00],
#        [-1.08827864e+00,  3.50688069e-01,  1.46310995e+00],
#        [-1.08827864e+00,  8.93421587e-01,  8.86396206e-02],
#        [-1.08827864e+00,  5.61559053e-01, -1.37990602e-01],
#        [-1.08827864e+00,  3.57601871e-01,  1.13995204e+00],
#        [-1.08827864e+00,  4.47481308e-01,  1.07490077e+00],
#        [-1.08827864e+00, -8.52313615e-01, -9.81558651e-01],
#        [-1.08827864e+00, -1.24294347e+00, -4.90526503e-01],
#        [-1.08827864e+00,  4.19826096e-01,  1.85761441e+00],
#        [-1.08827864e+00, -1.04935699e+00,  1.93945310e+00],
#        [-1.08827864e+00,  6.03083520e-02, -1.51665779e+00],
#        [-1.08827864e+00,  1.08700806e+00,  6.46821464e-01],
#        [-1.08827864e+00,  1.50183623e+00,  6.09049760e-01],
#        [-1.08827864e+00, -2.33528266e-01, -5.09412354e-01],
#        [-1.08827864e+00, -2.09329956e-01, -1.39914582e+00],
#        [-1.08827864e+00, -5.30821786e-01, -4.82132791e-01],
#        [-1.08827864e+00,  9.21076798e-01, -2.34518289e-01],
#        [-1.08827864e+00,  7.75886940e-01,  1.80725214e+00],
#        [-1.08827864e+00, -2.57726576e-01, -8.74538823e-01],
#        [-1.08827864e+00, -1.15993619e-01,  1.64147633e+00],
#        [-1.08827864e+00, -3.33778406e-01, -1.92585124e+00],
#        [-1.08827864e+00, -1.38121953e+00, -5.80758906e-01],
#        [-4.24108586e-01, -1.38467643e+00, -1.60059491e+00],
#        [-4.24108586e-01,  1.46726722e+00,  7.87416139e-01],
#        [-4.24108586e-01, -5.89589109e-01,  1.55753921e+00],
#        [-4.24108586e-01, -3.99417883e-02, -3.31045976e-01],
#        [-4.24108586e-01, -1.67847140e-01, -6.98270873e-01],
#        [-4.24108586e-01,  9.07249192e-01,  5.54490633e-01],
#        [-4.24108586e-01, -5.44649391e-01, -3.96097243e-01],
#        [-4.24108586e-01,  2.64265534e-01,  2.69104427e-01],
#        [-4.24108586e-01,  3.64515674e-01,  3.95010106e-01],
#        [-4.24108586e-01,  9.45275108e-01,  1.10427876e+00],
#        [-4.24108586e-01,  1.53686339e-02, -5.30396634e-01],
#        [-4.24108586e-01,  1.05248070e-01,  1.15919184e-01],
#        [-4.24108586e-01,  2.02382834e+00,  1.34805036e-01],
#        [-4.24108586e-01,  1.16305990e+00,  8.62959546e-01],
#        [-4.24108586e-01, -1.79950460e+00, -1.27114171e+00],
#        [-4.24108586e-01, -1.58863361e+00, -8.70341967e-01],
#        [-4.24108586e-01, -7.41692770e-01, -4.17081523e-01],
#        [-4.24108586e-01,  1.46035341e+00,  5.04128361e-01],
#        [-4.24108586e-01, -7.27865165e-01, -1.56702006e+00],
#        [-4.24108586e-01,  1.80950046e+00,  4.85242509e-01],
#        [-4.24108586e-01, -3.47606012e-01, -2.68093136e-01],
#        [-4.24108586e-01,  1.08009426e+00, -2.21927721e-01],
#        [-4.24108586e-01, -2.71554181e-01, -5.07313926e-01],
#        [-4.24108586e-01,  2.39717369e+00,  4.64258229e-01],
#        [-4.24108586e-01,  1.44998271e+00, -3.75112964e-01],
#        [-4.24108586e-01,  9.52188910e-01, -5.32495062e-01],
#        [-4.24108586e-01,  9.66016516e-01, -1.10711038e-01],
#        [-4.24108586e-01, -1.59209051e+00, -7.42337861e-01],
#        [-4.24108586e-01, -9.73305163e-01, -1.43901595e+00],
#        [-4.24108586e-01, -1.31553840e+00, -1.31940556e+00],
#        [-4.24108586e-01, -1.12886573e+00, -2.70191564e-01],
#        [-4.24108586e-01, -8.82967582e-03, -9.47983803e-01],
#        [-4.24108586e-01, -1.25677108e+00, -6.64696025e-01],
#        [-4.24108586e-01, -4.96252772e-01, -6.87778733e-01],
#        [-4.24108586e-01,  7.13662715e-01,  1.17352689e+00],
#        [-4.24108586e-01, -1.92003800e-02,  6.88790024e-01],
#        [-4.24108586e-01,  7.10205813e-01, -3.93644864e-02],
#        [ 2.40061464e-01,  1.34281877e+00,  4.85242509e-01],
#        [ 2.40061464e-01, -1.54369389e+00, -1.29212599e+00],
#        [ 2.40061464e-01,  1.12157708e+00,  1.02663693e+00],
#        [ 2.40061464e-01, -5.75761504e-01, -1.18510616e+00],
#        [ 2.40061464e-01, -1.78217844e-01, -9.98346074e-01],
#        [ 2.40061464e-01,  5.20076237e-01, -1.63171737e-01],
#        [ 2.40061464e-01,  1.27368074e+00,  9.17518674e-01],
#        [ 2.40061464e-01, -1.88588548e-01,  1.89328769e+00],
#        [ 2.40061464e-01,  1.77838834e+00,  2.92187135e-01],
#        [ 2.40061464e-01, -1.67847140e-01, -1.49567351e+00],
#        [ 2.40061464e-01,  2.64265534e-01,  3.76124254e-01],
#        [ 2.40061464e-01, -4.99709673e-01, -3.70916108e-01],
#        [ 2.40061464e-01,  2.12412013e-01, -4.92624931e-01],
#        [ 2.40061464e-01,  6.79093701e-01, -5.19550543e-02],
#        [ 2.40061464e-01, -1.56097840e+00, -1.18300774e+00],
#        [ 2.40061464e-01, -1.54023699e+00, -9.26999523e-01],
#        [ 2.40061464e-01,  6.72179898e-01,  9.04928106e-01],
#        [ 2.40061464e-01,  1.53686339e-02, -7.84306420e-01],
#        [ 2.40061464e-01,  8.38111165e-01,  1.31621999e+00],
#        [ 2.40061464e-01, -5.51563194e-01,  1.10427876e+00],
#        [ 2.40061464e-01, -1.17034854e+00,  1.89328769e+00],
#        [ 2.40061464e-01, -8.97253333e-01,  1.30362942e+00],
#        [ 2.40061464e-01,  1.01441314e+00,  4.30683382e-01],
#        [ 2.40061464e-01, -1.61283192e+00, -3.89801959e-01],
#        [ 2.40061464e-01,  1.25985313e+00, -2.24026149e-01],
#        [ 2.40061464e-01, -1.23948657e+00, -6.58400741e-01],
#        [ 2.40061464e-01, -8.17744601e-01, -1.67823674e+00],
#        [ 2.40061464e-01, -1.92003800e-02,  5.77573341e-01],
#        [ 2.40061464e-01, -1.12886573e+00, -4.54853227e-01],
#        [ 2.40061464e-01, -8.45399812e-01, -1.86254445e-01],
#        [ 2.40061464e-01,  4.33653702e-01,  3.08974559e-01],
#        [ 2.40061464e-01, -6.41400981e-02, -5.40534823e-02],
#        [ 2.40061464e-01,  2.78093139e-01,  1.85167308e-01],
#        [ 2.40061464e-01,  3.29946660e-01,  1.48199580e+00],
#        [ 9.04231513e-01, -5.13537279e-01, -4.06589383e-01],
#        [ 9.04231513e-01, -1.94123755e+00, -9.37491663e-01],
#        [ 9.04231513e-01, -1.55406460e+00, -4.08687811e-01],
#        [ 9.04231513e-01,  1.51220694e+00,  1.09168820e+00],
#        [ 9.04231513e-01,  5.51188349e-01,  1.34979484e+00],
#        [ 9.04231513e-01, -2.95752491e-01,  8.00006707e-01],
#        [ 9.04231513e-01,  1.46726722e+00, -3.24750692e-01],
#        [ 9.04231513e-01,  8.20826658e-01,  1.34805036e-01],
#        [ 9.04231513e-01,  8.86507784e-01, -2.13534009e-01],
#        [ 9.04231513e-01, -7.07123756e-01, -4.50656371e-01],
#        [ 9.04231513e-01, -1.21528826e+00, -2.70191564e-01],
#        [ 9.04231513e-01, -1.30862460e+00,  1.44002724e+00],
#        [ 9.04231513e-01, -1.98959252e-01, -1.49357508e+00],
#        [ 9.04231513e-01, -1.51603868e+00, -1.39285054e+00],
#        [ 9.04231513e-01,  3.43774266e-01,  3.06876131e-01],
#        [ 9.04231513e-01, -1.56789220e+00, -1.14523603e+00],
#        [ 9.04231513e-01,  1.70929196e-01,  5.29309497e-01],
#        [ 9.04231513e-01, -3.09580097e-01, -3.07963268e-01],
#        [ 9.04231513e-01, -1.10466742e+00, -7.67518996e-01],
#        [ 9.04231513e-01, -1.29821224e-01,  1.75479144e+00],
#        [ 9.04231513e-01, -1.54023699e+00,  2.32136699e+00],
#        [ 9.04231513e-01,  1.54102834e-03, -8.47259260e-01],
#        [ 9.04231513e-01,  2.64265534e-01,  1.62468890e+00],
#        [ 9.04231513e-01,  6.75636799e-01,  2.48120147e-01],
#        [ 9.04231513e-01,  1.20799961e+00,  1.20710174e+00],
#        [ 9.04231513e-01, -9.62934459e-01, -1.60898862e+00],
#        [ 9.04231513e-01,  1.63319848e+00,  8.27286270e-01],
#        [ 9.04231513e-01, -1.92045449e-01,  6.32132468e-01],
#        [ 9.04231513e-01, -8.07373897e-01,  9.61585661e-01],
#        [ 9.04231513e-01, -1.30171080e+00, -1.45160652e+00],
#        [ 9.04231513e-01,  2.22824367e-02, -5.72365194e-01],
#        [ 9.04231513e-01,  1.76456074e+00, -1.06514182e-01],
#        [ 9.04231513e-01,  5.85757363e-01, -1.65270165e-01],
#        [ 1.56840156e+00,  7.93171447e-01, -2.61797853e-01],
#        [ 1.56840156e+00,  1.76801764e+00,  9.63684089e-01],
#        [ 1.56840156e+00,  5.33945492e-02,  3.76124254e-01],
#        [ 1.56840156e+00, -4.33986897e-02,  1.95414210e+00],
#        [ 1.56840156e+00, -1.14615023e+00,  7.49644435e-01],
#        [ 1.56840156e+00,  1.20454271e+00,  1.31412156e+00],
#        [ 1.56840156e+00, -1.28096939e+00, -1.26694486e+00],
#        [ 1.56840156e+00, -1.34319361e+00,  2.03807922e+00],
#        [ 2.23257161e+00, -3.96002631e-01, -1.25855114e+00],
#        [ 2.23257161e+00, -1.03898629e+00,  2.03807922e+00],
#        [ 2.23257161e+00,  4.64807464e-02,  2.79596567e-01],
#        [ 2.89674166e+00, -3.47606012e-01, -1.26274800e+00],
#        [ 3.56091171e+00, -4.06373336e-01, -1.22077944e+00],
#        [ 4.22508176e+00, -3.57976716e-01, -1.25855114e+00]])

# %%
stores= sorted(storemap['Store_Name'].unique())
stores
# Out:
# [u'49ers Team Store',
#  u'Abercrombie & Fitch',
#  u'Adidas',
#  u'Ajisen Ramen',
#  u'Aldo',
#  u'Amazon Pop-Up',
#  u'American Eagle Outfitters',
#  u'Amiri Salon',
#  u'Amoura Cafe Fresh Mediterranean',
#  u'Andale Mexican Restaurant',
#  u'Aritzia',
#  u"Auntie Anne's Pretzels",
#  u'Aveda',
#  u'BCBGMAXAZRIA',
#  u'BOSS',
#  u'Banana Republic',
#  u'Bath & Body Works',
#  u"Beard Papa's Cream Puffs",
#  u'Bespoke Coworking',
#  u'Bespoke Events',
#  u"Bloomingdale's",
#  u'Bose',
#  u'Brighton Collectibles',
#  u'Bristol Farms',
#  u'Brookstone',
#  u'Buckhorn Grill',
#  u'Burberry',
#  u'Burke Williams Day Spa',
#  u'Cafe Bellini',
#  u'Caffe Central',
#  u'Cako Bakery',
#  u'Camper',
#  u'Century San Francisco Centre 9',
#  u'Champs Sports',
#  u"Charley's Grilled Subs",
#  u'Chipotle',
#  u"Claire's Boutique",
#  u'Clarks',
#  u'Club Monaco Men',
#  u'Club Monaco Women',
#  u'Coach',
#  u'Coriander Gourmet Thai',
#  u'Corner W',
#  u'Cotton On',
#  u'Currency Exchange International ',
#  u'DAVIDsTEA',
#  u'Dyson',
#  u'ECCO',
#  u'Eddie Bauer',
#  u'Express',
#  u'Eyebrow Plus',
#  u'Finish Line',
#  u'Fire of Brazil',
#  u'Forever Flawless',
#  u'Forever Flawless ',
#  u'Fossil',
#  u"Francesca's Collection ",
#  u'GNC',
#  u'GUESS ',
#  u'Ghirardelli Ice Cream and Chocolate Shop ',
#  u'Go! Toys and Games',
#  u'Godiva Chocolatier',
#  u'H&M',
#  u'H&M Man',
#  u'Haagen Dazs',
#  u'Hallmark',
#  u'Hollister Co.',
#  u'House of Hoops by Foot Locker',
#  u'J.Crew',
#  u'Jamba Juice',
#  u'Janie And Jack',
#  u'Karen Millen',
#  u'Kate Spade New York',
#  u'Kay Jewelers',
#  u'Kichi Grill',
#  u"Kiehl's",
#  u"L'Occitane en Provence",
#  u'LEGO',
#  u'Lady Foot Locker',
#  u'Lids',
#  u'Lobster Me',
#  u'Loving Hut Vegan Cuisine ',
#  u'Lucky Brand Jeans',
#  u'M.Y. China',
#  u'Madewell',
#  u'Marbles: The Brain Store',
#  u'Max & Co.',
#  u'Michael Kors',
#  u'Michael Kors Men',
#  u'Microsoft',
#  u'Mrs. Fields',
#  u'NYS Collection',
#  u'New Era',
#  u'Nordstrom',
#  u'Nordstrom E-Bar',
#  u'OAK+FORT',
#  u'Onassis',
#  u'Optica',
#  u'Origins',
#  u'PacSun',
#  u'Panda Express',
#  u'Pandora',
#  u'Papyrus',
#  u'Pasta Moto',
#  u"Peet's Coffee & Tea",
#  u'Penhaligon\xef\xbf\xbd\xdb\xaas',
#  u'Perfumania',
#  u'Pressed Juicery',
#  u'ProActiv Solutions ',
#  u'RED Valentino',
#  u'Razer',
#  u'Rolex',
#  u'SF Sports',
#  u'Samsonite',
#  u'San Francisco Luggage Co.',
#  u'San Francisco Soup Company',
#  u'Sarku Japan',
#  u'Shoe Palace ',
#  u'Shoe Wiz',
#  u'Solstice',
#  u'Sorabol Korean BBQ & Asian Noodles',
#  u'Starbucks',
#  u'Steve Madden',
#  u'Studio Manhattan',
#  u'Sunglass Hut',
#  u'Sunglass Hut ',
#  u'Superdry ',
#  u'Sur La Table',
#  u'Swarovski',
#  u'Swatch',
#  u'T-Mobile',
#  u'TAP 415',
#  u'Teavana',
#  u'The Art of Shaving',
#  u'The Body Shop',
#  u'The Walking Company',
#  u'Tiffany & Co.',
#  u'Timberland',
#  u'Tory Burch ',
#  u'Tourneau',
#  u'True Religion Jeans',
#  u'Tumi',
#  u'Vans',
#  u'Vera Bradley',
#  u"Victoria's Secret",
#  u'Warriors Team Store',
#  u"Wetzel's Pretzels",
#  u'Yoppi Frozen Yogurt ',
#  u'Zara',
#  u'abercrombie kids',
#  u'bareMinerals',
#  u'bebe',
#  u'iPlay n Talk',
#  u'lululemon athletica']

# %%
store_mapping = dict(zip(stores, range(0, len(stores) + 1)))
store_mapping
# Out:
# {u'49ers Team Store': 0,
#  u'Abercrombie & Fitch': 1,
#  u'Adidas': 2,
#  u'Ajisen Ramen': 3,
#  u'Aldo': 4,
#  u'Amazon Pop-Up': 5,
#  u'American Eagle Outfitters': 6,
#  u'Amiri Salon': 7,
#  u'Amoura Cafe Fresh Mediterranean': 8,
#  u'Andale Mexican Restaurant': 9,
#  u'Aritzia': 10,
#  u"Auntie Anne's Pretzels": 11,
#  u'Aveda': 12,
#  u'BCBGMAXAZRIA': 13,
#  u'BOSS': 14,
#  u'Banana Republic': 15,
#  u'Bath & Body Works': 16,
#  u"Beard Papa's Cream Puffs": 17,
#  u'Bespoke Coworking': 18,
#  u'Bespoke Events': 19,
#  u"Bloomingdale's": 20,
#  u'Bose': 21,
#  u'Brighton Collectibles': 22,
#  u'Bristol Farms': 23,
#  u'Brookstone': 24,
#  u'Buckhorn Grill': 25,
#  u'Burberry': 26,
#  u'Burke Williams Day Spa': 27,
#  u'Cafe Bellini': 28,
#  u'Caffe Central': 29,
#  u'Cako Bakery': 30,
#  u'Camper': 31,
#  u'Century San Francisco Centre 9': 32,
#  u'Champs Sports': 33,
#  u"Charley's Grilled Subs": 34,
#  u'Chipotle': 35,
#  u"Claire's Boutique": 36,
#  u'Clarks': 37,
#  u'Club Monaco Men': 38,
#  u'Club Monaco Women': 39,
#  u'Coach': 40,
#  u'Coriander Gourmet Thai': 41,
#  u'Corner W': 42,
#  u'Cotton On': 43,
#  u'Currency Exchange International ': 44,
#  u'DAVIDsTEA': 45,
#  u'Dyson': 46,
#  u'ECCO': 47,
#  u'Eddie Bauer': 48,
#  u'Express': 49,
#  u'Eyebrow Plus': 50,
#  u'Finish Line': 51,
#  u'Fire of Brazil': 52,
#  u'Forever Flawless': 53,
#  u'Forever Flawless ': 54,
#  u'Fossil': 55,
#  u"Francesca's Collection ": 56,
#  u'GNC': 57,
#  u'GUESS ': 58,
#  u'Ghirardelli Ice Cream and Chocolate Shop ': 59,
#  u'Go! Toys and Games': 60,
#  u'Godiva Chocolatier': 61,
#  u'H&M': 62,
#  u'H&M Man': 63,
#  u'Haagen Dazs': 64,
#  u'Hallmark': 65,
#  u'Hollister Co.': 66,
#  u'House of Hoops by Foot Locker': 67,
#  u'J.Crew': 68,
#  u'Jamba Juice': 69,
#  u'Janie And Jack': 70,
#  u'Karen Millen': 71,
#  u'Kate Spade New York': 72,
#  u'Kay Jewelers': 73,
#  u'Kichi Grill': 74,
#  u"Kiehl's": 75,
#  u"L'Occitane en Provence": 76,
#  u'LEGO': 77,
#  u'Lady Foot Locker': 78,
#  u'Lids': 79,
#  u'Lobster Me': 80,
#  u'Loving Hut Vegan Cuisine ': 81,
#  u'Lucky Brand Jeans': 82,
#  u'M.Y. China': 83,
#  u'Madewell': 84,
#  u'Marbles: The Brain Store': 85,
#  u'Max & Co.': 86,
#  u'Michael Kors': 87,
#  u'Michael Kors Men': 88,
#  u'Microsoft': 89,
#  u'Mrs. Fields': 90,
#  u'NYS Collection': 91,
#  u'New Era': 92,
#  u'Nordstrom': 93,
#  u'Nordstrom E-Bar': 94,
#  u'OAK+FORT': 95,
#  u'Onassis': 96,
#  u'Optica': 97,
#  u'Origins': 98,
#  u'PacSun': 99,
#  u'Panda Express': 100,
#  u'Pandora': 101,
#  u'Papyrus': 102,
#  u'Pasta Moto': 103,
#  u"Peet's Coffee & Tea": 104,
#  u'Penhaligon\xef\xbf\xbd\xdb\xaas': 105,
#  u'Perfumania': 106,
#  u'Pressed Juicery': 107,
#  u'ProActiv Solutions ': 108,
#  u'RED Valentino': 109,
#  u'Razer': 110,
#  u'Rolex': 111,
#  u'SF Sports': 112,
#  u'Samsonite': 113,
#  u'San Francisco Luggage Co.': 114,
#  u'San Francisco Soup Company': 115,
#  u'Sarku Japan': 116,
#  u'Shoe Palace ': 117,
#  u'Shoe Wiz': 118,
#  u'Solstice': 119,
#  u'Sorabol Korean BBQ & Asian Noodles': 120,
#  u'Starbucks': 121,
#  u'Steve Madden': 122,
#  u'Studio Manhattan': 123,
#  u'Sunglass Hut': 124,
#  u'Sunglass Hut ': 125,
#  u'Superdry ': 126,
#  u'Sur La Table': 127,
#  u'Swarovski': 128,
#  u'Swatch': 129,
#  u'T-Mobile': 130,
#  u'TAP 415': 131,
#  u'Teavana': 132,
#  u'The Art of Shaving': 133,
#  u'The Body Shop': 134,
#  u'The Walking Company': 135,
#  u'Tiffany & Co.': 136,
#  u'Timberland': 137,
#  u'Tory Burch ': 138,
#  u'Tourneau': 139,
#  u'True Religion Jeans': 140,
#  u'Tumi': 141,
#  u'Vans': 142,
#  u'Vera Bradley': 143,
#  u"Victoria's Secret": 144,
#  u'Warriors Team Store': 145,
#  u"Wetzel's Pretzels": 146,
#  u'Yoppi Frozen Yogurt ': 147,
#  u'Zara': 148,
#  u'abercrombie kids': 149,
#  u'bareMinerals': 150,
#  u'bebe': 151,
#  u'iPlay n Talk': 152,
#  u'lululemon athletica': 153}

# %%
storemap['Store_Index'] = storemap['Store_Name'].map(store_mapping).astype(int)
storemap.head()
# Out:
#                            Store_Name  Floor_Index   latitude   longitude  \
# 0                         Jamba Juice            0  37.784091 -122.406813
# 1              Coriander Gourmet Thai            0  37.784596 -122.406210
# 2                      NYS Collection            0  37.784396 -122.406587
# 3                            Hallmark            0  37.783771 -122.407377
# 4  Sorabol Korean BBQ & Asian Noodles            0  37.784601 -122.406328
#
#    Store_Index
# 0           69
# 1           41
# 2           91
# 3           65
# 4          120

# %%
y = storemap['Store_Index'].as_matrix().astype(np.int)
y
# Out:
# array([ 69,  41,  91,  65, 120, 103,   1,  52, 108,  42,  25,  30,  36,
#         23,  99,  45,   9, 125, 104, 100,  57,  92,  77,  90,  17,   3,
#        117,  81,  59,  85,  29, 107,  28, 116,  74,  20, 145,  80,   8,
#        146, 118,  64, 127,  34,  33, 115, 121,  35, 110,  84,  20, 129,
#         75,   5,  70, 133, 109,  26, 128,  22,  87,  71,  10, 141,  72,
#        105,   1, 138,  76, 111, 124, 137, 139,   2, 126,  98,  38,  44,
#         39,   6,  94,  75, 136,  14,  88, 153,  40, 150,  54,  95,  11,
#         86,  96, 148, 151,  47,  78,  43, 101, 134,  49, 130,  24,  13,
#         63,  20,   0, 123,  56,   2,  46,  66,  89, 113,  58,  12,  31,
#        147,  68, 135,  49, 102, 114,  15, 143,  48,  61, 112,   4,  67,
#        149, 144, 106,  73,   7,  37,  79, 152,  60,  20,  55, 142,  50,
#        140,  51,  82,  16,  62, 132, 122,  53, 119, 131,  97,  83,  18,
#         19,  21,  93,  20,  93,  32,  27,  93,  93,  93])

# %%
'''CROSS VALIDATION and checking the accuracy of our classifiers'''
# Out:
# 'CROSS VALIDATION and checking the accuracy of our classifiers'

# %%
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
# Out:
# C:\Users\welcome\Anaconda2\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def stratified_cv(X, y, clf_class, shuffle=True, n_folds=2, **kwargs):
    stratified_k_fold = cross_validation.StratifiedKFold(y, n_folds=n_folds, shuffle=shuffle)
    y_pred = y.copy()
    for ii, jj in stratified_k_fold:
        X_train, X_test = X[ii], X[jj]
        y_train = y[ii]
        clf = clf_class(**kwargs)
        clf.fit(X_train,y_train)
        y_pred[jj] = clf.predict(X_test)
    return y_pred

# %%
print('Passive Aggressive Classifier: {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, linear_model.PassiveAggressiveClassifier))))
print('Gradient Boosting Classifier:  {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, ensemble.GradientBoostingClassifier))))
print('Support vector machine(SVM):   {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, svm.SVC))))
print('Random Forest Classifier:      {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, ensemble.RandomForestClassifier))))
print('K Nearest Neighbor Classifier: {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, neighbors.KNeighborsClassifier))))
print('Logistic Regression:           {:.2f}'.format(metrics.accuracy_score(y, stratified_cv(X, y, linear_model.LogisticRegression))))
# Out:
# C:\Users\welcome\Anaconda2\lib\site-packages\sklearn\cross_validation.py:553: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=2.
#   % (min_labels, self.n_folds)), Warning)
# C:\Users\welcome\Anaconda2\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.passive_aggressive.PassiveAggressiveClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Passive Aggressive Classifier: 0.01
# Gradient Boosting Classifier:  0.05
# Support vector machine(SVM):   0.05
# Random Forest Classifier:      0.05
# K Nearest Neighbor Classifier: 0.05
# Logistic Regression:           0.07

# %%
'''print('Misclassified samples: %d' % (y != y_pred).sum())'''
# Out:
# "print('Misclassified samples: %d' % (y != y_pred).sum())"

# %%
'''#OR:
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=2)
skf.get_n_splits(X, y)

print(skf)  

for train_index, test_index in skf.split(X, y):
   print("TRAIN:", train_index, "TEST:", test_index)
   X_train, X_test = X[train_index], X[test_index]
   y_train, y_test = y[train_index], y[test_index]
'''
# Out:
# '#OR:\nfrom sklearn.model_selection import StratifiedKFold\nskf = StratifiedKFold(n_splits=2)\nskf.get_n_splits(X, y)\n\nprint(skf)  \n\nfor train_index, test_index in skf.split(X, y):\n   print("TRAIN:", train_index, "TEST:", test_index)\n   X_train, X_test = X[train_index], X[test_index]\n   y_train, y_test = y[train_index], y[test_index]\n'

# %%
#RANDOM FOREST TRAINING: SKIPPING CROSS VALIDATION:
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100)
#Fit the training data and create the decision trees:

train_features = X

#labels
train_target = y

# Fit the model to our training data
clf = clf.fit(train_features, train_target)
score = clf.score(train_features, train_target)
"Mean accuracy of Random Forest: {0}".format(score)
# Out:
# 'Mean accuracy of Random Forest: 1.0'

# %%
X_test = pinginfo.drop(['Shopper_ID'], axis=1).as_matrix().astype(np.float)
X_test
# Out:
# array([[   4.        ,   37.66146302, -122.2986728 ],
#        [   1.        ,   37.78406211, -122.4069432 ],
#        [   4.        ,   37.78436125, -122.4067095 ],
#        ...,
#        [   2.        ,   36.0179502 , -116.704627  ],
#        [   1.        ,   37.78404745, -122.4069997 ],
#        [   0.        ,   37.78407819, -122.4070869 ]])

# %%
scaler = preprocessing.StandardScaler()
test_data = scaler.fit_transform(X_test)
test_data
# Out:
# array([[ 1.83464372,  0.36209925, -0.40275272],
#        [-0.32798594,  0.42248019, -0.41922354],
#        [ 1.83464372,  0.42262752, -0.41918799],
#        ...,
#        [ 0.39289061, -0.44734271,  0.44825139],
#        [-0.32798594,  0.42247297, -0.41923214],
#        [-1.04886249,  0.42248811, -0.4192454 ]])

# %%
test_y = clf.predict(test_data)

# %%
pinginfo['Store_Index'] = test_y

# %%
pinginfo.sort_values(['Shopper_ID'], axis=0, ascending=True, inplace=True, kind='quicksort', na_position='last')

# %%
pinginfo.head(100)
# Out:
#        Shopper_ID  Floor_Index   latitude   longitude  Store_Index
# 35181   Shopper_1            3  37.762391 -122.388008          119
# 70238   Shopper_1            0  33.585825 -108.806374           20
# 70264   Shopper_1            0  37.784023 -122.406786          108
# 40491   Shopper_1            2  37.761052 -122.386801           43
# 4777    Shopper_1            3  35.664542 -115.588398           16
# 4776    Shopper_1            0  32.386375 -104.920369           20
# 101158  Shopper_1            1  34.005662 -110.166421           20
# 49054   Shopper_1            0  35.399517 -114.736228           99
# 22621   Shopper_1            1  32.721647 -106.064451           20
# 22620   Shopper_1            0  17.523494  -56.901809           20
# 22619   Shopper_1            2  34.349167 -111.279150            0
# 52049   Shopper_1            3  31.486702 -102.005952           20
# 95887   Shopper_1            1  33.061045 -107.106172           20
# 98815   Shopper_1            0  37.784038 -122.406711          108
# 78061   Shopper_1            1  31.971133 -103.575228           20
# 106999  Shopper_1            0  33.061063 -107.106165           20
# 78035   Shopper_1            0  37.784263 -122.405984          108
# 77973   Shopper_1            3  37.784085 -122.407135          119
# 100499  Shopper_1            3  37.784018 -122.407150          119
# 35762   Shopper_1            3  37.784052 -122.407079          119
# 71239   Shopper_1            3  37.784055 -122.407086          119
# 97924   Shopper_1            0  37.784075 -122.407065          108
# 102120  Shopper_1            0  37.784055 -122.407176          108
# 97101   Shopper_1            2  33.787407 -109.504903           20
# 47032   Shopper_1            0  37.784077 -122.407172          108
# 25665   Shopper_1            0  34.349141 -111.278963          116
# 25664   Shopper_1            3  35.085205 -113.663751           62
# 77426   Shopper_1            2  37.784041 -122.407108           43
# 97946   Shopper_1            1  35.265121 -114.246687           20
# 32914   Shopper_1            0  37.784059 -122.406598          108
# ...           ...          ...        ...         ...          ...
# 418     Shopper_1            1  30.227255  -97.925648           20
# 37372   Shopper_1            0  37.784085 -122.407009          108
# 21770   Shopper_1            0  33.968828 -110.133960           20
# 28495   Shopper_1            2  35.561458 -115.206698           63
# 28513   Shopper_1            1  34.349118 -111.279163           39
# 93921   Shopper_1            2  37.784079 -122.407114           43
# 50871   Shopper_1            1  33.565384 -108.788102           20
# 61183   Shopper_1            0  31.971140 -103.575216           20
# 50835   Shopper_1            3  34.877596 -112.991172           62
# 21547   Shopper_1            3  37.784064 -122.407207          119
# 61182   Shopper_1            4  35.756717 -115.930223           19
# 74866   Shopper_1            1  37.757750 -122.383892          128
# 74855   Shopper_1            2  37.762391 -122.388008           43
# 55291   Shopper_1            2  37.783956 -122.407213           43
# 74843   Shopper_1            3  37.784077 -122.407058          119
# 74806   Shopper_1            0  37.784168 -122.406034          108
# 74805   Shopper_1            1  34.635384 -112.206523           39
# 41665   Shopper_1            1  35.539867 -115.187304           14
# 50625   Shopper_1            0  35.644070 -115.570418           64
# 50624   Shopper_1            3  37.784065 -122.407157          119
# 93848   Shopper_1            1  32.746176 -106.086128           20
# 11819   Shopper_1            2  37.784077 -122.407058           43
# 85044   Shopper_1            0  28.338040  -91.805298           20
# 85045   Shopper_1            3  35.539812 -115.187564           62
# 11637   Shopper_1            0  37.784120 -122.406620          108
# 60944   Shopper_1            0  37.784048 -122.407212          108
# 85061   Shopper_1            2  34.635388 -112.206498            0
# 85080   Shopper_1            1  32.386344 -104.920316           20
# 74419   Shopper_1            1  33.585855 -108.806241           20
# 61181   Shopper_1            1  37.784032 -122.407175          128
#
# [100 rows x 5 columns]

# %%
#now convert these store_index back into store_name

# %%
store_mapping
# Out:
# {u'49ers Team Store': 0,
#  u'Abercrombie & Fitch': 1,
#  u'Adidas': 2,
#  u'Ajisen Ramen': 3,
#  u'Aldo': 4,
#  u'Amazon Pop-Up': 5,
#  u'American Eagle Outfitters': 6,
#  u'Amiri Salon': 7,
#  u'Amoura Cafe Fresh Mediterranean': 8,
#  u'Andale Mexican Restaurant': 9,
#  u'Aritzia': 10,
#  u"Auntie Anne's Pretzels": 11,
#  u'Aveda': 12,
#  u'BCBGMAXAZRIA': 13,
#  u'BOSS': 14,
#  u'Banana Republic': 15,
#  u'Bath & Body Works': 16,
#  u"Beard Papa's Cream Puffs": 17,
#  u'Bespoke Coworking': 18,
#  u'Bespoke Events': 19,
#  u"Bloomingdale's": 20,
#  u'Bose': 21,
#  u'Brighton Collectibles': 22,
#  u'Bristol Farms': 23,
#  u'Brookstone': 24,
#  u'Buckhorn Grill': 25,
#  u'Burberry': 26,
#  u'Burke Williams Day Spa': 27,
#  u'Cafe Bellini': 28,
#  u'Caffe Central': 29,
#  u'Cako Bakery': 30,
#  u'Camper': 31,
#  u'Century San Francisco Centre 9': 32,
#  u'Champs Sports': 33,
#  u"Charley's Grilled Subs": 34,
#  u'Chipotle': 35,
#  u"Claire's Boutique": 36,
#  u'Clarks': 37,
#  u'Club Monaco Men': 38,
#  u'Club Monaco Women': 39,
#  u'Coach': 40,
#  u'Coriander Gourmet Thai': 41,
#  u'Corner W': 42,
#  u'Cotton On': 43,
#  u'Currency Exchange International ': 44,
#  u'DAVIDsTEA': 45,
#  u'Dyson': 46,
#  u'ECCO': 47,
#  u'Eddie Bauer': 48,
#  u'Express': 49,
#  u'Eyebrow Plus': 50,
#  u'Finish Line': 51,
#  u'Fire of Brazil': 52,
#  u'Forever Flawless': 53,
#  u'Forever Flawless ': 54,
#  u'Fossil': 55,
#  u"Francesca's Collection ": 56,
#  u'GNC': 57,
#  u'GUESS ': 58,
#  u'Ghirardelli Ice Cream and Chocolate Shop ': 59,
#  u'Go! Toys and Games': 60,
#  u'Godiva Chocolatier': 61,
#  u'H&M': 62,
#  u'H&M Man': 63,
#  u'Haagen Dazs': 64,
#  u'Hallmark': 65,
#  u'Hollister Co.': 66,
#  u'House of Hoops by Foot Locker': 67,
#  u'J.Crew': 68,
#  u'Jamba Juice': 69,
#  u'Janie And Jack': 70,
#  u'Karen Millen': 71,
#  u'Kate Spade New York': 72,
#  u'Kay Jewelers': 73,
#  u'Kichi Grill': 74,
#  u"Kiehl's": 75,
#  u"L'Occitane en Provence": 76,
#  u'LEGO': 77,
#  u'Lady Foot Locker': 78,
#  u'Lids': 79,
#  u'Lobster Me': 80,
#  u'Loving Hut Vegan Cuisine ': 81,
#  u'Lucky Brand Jeans': 82,
#  u'M.Y. China': 83,
#  u'Madewell': 84,
#  u'Marbles: The Brain Store': 85,
#  u'Max & Co.': 86,
#  u'Michael Kors': 87,
#  u'Michael Kors Men': 88,
#  u'Microsoft': 89,
#  u'Mrs. Fields': 90,
#  u'NYS Collection': 91,
#  u'New Era': 92,
#  u'Nordstrom': 93,
#  u'Nordstrom E-Bar': 94,
#  u'OAK+FORT': 95,
#  u'Onassis': 96,
#  u'Optica': 97,
#  u'Origins': 98,
#  u'PacSun': 99,
#  u'Panda Express': 100,
#  u'Pandora': 101,
#  u'Papyrus': 102,
#  u'Pasta Moto': 103,
#  u"Peet's Coffee & Tea": 104,
#  u'Penhaligon\xef\xbf\xbd\xdb\xaas': 105,
#  u'Perfumania': 106,
#  u'Pressed Juicery': 107,
#  u'ProActiv Solutions ': 108,
#  u'RED Valentino': 109,
#  u'Razer': 110,
#  u'Rolex': 111,
#  u'SF Sports': 112,
#  u'Samsonite': 113,
#  u'San Francisco Luggage Co.': 114,
#  u'San Francisco Soup Company': 115,
#  u'Sarku Japan': 116,
#  u'Shoe Palace ': 117,
#  u'Shoe Wiz': 118,
#  u'Solstice': 119,
#  u'Sorabol Korean BBQ & Asian Noodles': 120,
#  u'Starbucks': 121,
#  u'Steve Madden': 122,
#  u'Studio Manhattan': 123,
#  u'Sunglass Hut': 124,
#  u'Sunglass Hut ': 125,
#  u'Superdry ': 126,
#  u'Sur La Table': 127,
#  u'Swarovski': 128,
#  u'Swatch': 129,
#  u'T-Mobile': 130,
#  u'TAP 415': 131,
#  u'Teavana': 132,
#  u'The Art of Shaving': 133,
#  u'The Body Shop': 134,
#  u'The Walking Company': 135,
#  u'Tiffany & Co.': 136,
#  u'Timberland': 137,
#  u'Tory Burch ': 138,
#  u'Tourneau': 139,
#  u'True Religion Jeans': 140,
#  u'Tumi': 141,
#  u'Vans': 142,
#  u'Vera Bradley': 143,
#  u"Victoria's Secret": 144,
#  u'Warriors Team Store': 145,
#  u"Wetzel's Pretzels": 146,
#  u'Yoppi Frozen Yogurt ': 147,
#  u'Zara': 148,
#  u'abercrombie kids': 149,
#  u'bareMinerals': 150,
#  u'bebe': 151,
#  u'iPlay n Talk': 152,
#  u'lululemon athletica': 153}

# %%
inv_class_mapping = {v: k for k, v in store_mapping.items()}
pinginfo['Store_Name'] = pinginfo['Store_Index'].map(inv_class_mapping)

# %%
pinginfo.groupby(['Shopper_ID', 'Store_Name']).describe()
# Out:
#                                          Floor_Index                           \
#                                                count      mean       std  min
# Shopper_ID Store_Name
# Shopper_1  49ers Team Store                      7.0  2.000000  0.000000  2.0
#            BOSS                                  1.0  1.000000       NaN  1.0
#            Bath & Body Works                     1.0  3.000000       NaN  3.0
#            Bespoke Events                        2.0  4.000000  0.000000  4.0
#            Bloomingdale's                       64.0  1.140625  1.125000  0.0
#            Bristol Farms                         1.0  0.000000       NaN  0.0
#            Club Monaco Women                     3.0  1.000000  0.000000  1.0
#            Cotton On                            14.0  2.000000  0.000000  2.0
#            H&M                                   9.0  3.000000  0.000000  3.0
#            H&M Man                               4.0  2.000000  0.000000  2.0
#            Haagen Dazs                           2.0  0.000000  0.000000  0.0
#            House of Hoops by Foot Locker         1.0  3.000000       NaN  3.0
#            Kay Jewelers                          1.0  3.000000       NaN  3.0
#            PacSun                                3.0  0.000000  0.000000  0.0
#            ProActiv Solutions                   30.0  0.000000  0.000000  0.0
#            RED Valentino                         1.0  1.000000       NaN  1.0
#            Sarku Japan                           2.0  0.000000  0.000000  0.0
#            Solstice                             17.0  3.000000  0.000000  3.0
#            Swarovski                            14.0  1.000000  0.000000  1.0
#            TAP 415                               8.0  4.000000  0.000000  4.0
#            The Walking Company                   2.0  3.000000  0.000000  3.0
#            abercrombie kids                      2.0  3.000000  0.000000  3.0
# Shopper_10 49ers Team Store                      2.0  2.000000  0.000000  2.0
#            Auntie Anne's Pretzels                1.0  2.000000       NaN  2.0
#            Bespoke Events                        4.0  4.000000  0.000000  4.0
#            Bloomingdale's                        4.0  1.750000  1.500000  1.0
#            Brighton Collectibles                 5.0  1.000000  0.000000  1.0
#            Bristol Farms                         1.0  0.000000       NaN  0.0
#            Camper                                2.0  2.000000  0.000000  2.0
#            Chipotle                              1.0  0.000000       NaN  0.0
# ...                                              ...       ...       ...  ...
# Shopper_98 Swarovski                            49.0  1.000000  0.000000  1.0
#            TAP 415                               1.0  4.000000       NaN  4.0
# Shopper_99 49ers Team Store                      3.0  2.000000  0.000000  2.0
#            BOSS                                  3.0  1.000000  0.000000  1.0
#            Bath & Body Works                     1.0  3.000000       NaN  3.0
#            Bespoke Events                        9.0  4.000000  0.000000  4.0
#            Bloomingdale's                        5.0  3.000000  1.414214  1.0
#            Brighton Collectibles                 3.0  1.000000  0.000000  1.0
#            Bristol Farms                         2.0  0.000000  0.000000  0.0
#            Camper                                5.0  2.000000  0.000000  2.0
#            Club Monaco Women                     3.0  1.000000  0.000000  1.0
#            Cotton On                            26.0  2.000000  0.000000  2.0
#            H&M                                   1.0  3.000000       NaN  3.0
#            H&M Man                               3.0  2.000000  0.000000  2.0
#            Haagen Dazs                           3.0  0.000000  0.000000  0.0
#            Janie And Jack                        2.0  1.000000  0.000000  1.0
#            Kay Jewelers                          1.0  3.000000       NaN  3.0
#            L'Occitane en Provence                3.0  1.000000  0.000000  1.0
#            Lady Foot Locker                      4.0  2.000000  0.000000  2.0
#            Lids                                  1.0  3.000000       NaN  3.0
#            M.Y. China                            1.0  4.000000       NaN  4.0
#            ProActiv Solutions                   51.0  0.000000  0.000000  0.0
#            Sarku Japan                           1.0  0.000000       NaN  0.0
#            Solstice                              7.0  3.000000  0.000000  3.0
#            Sunglass Hut                          1.0  0.000000       NaN  0.0
#            Swarovski                            28.0  1.000000  0.000000  1.0
#            Swatch                                2.0  1.000000  0.000000  1.0
#            TAP 415                              18.0  4.000000  0.000000  4.0
#            The Art of Shaving                    2.0  1.000000  0.000000  1.0
#            abercrombie kids                      1.0  3.000000       NaN  3.0
#
#                                                               Store_Index  \
#                                           25%  50%   75%  max       count
# Shopper_ID Store_Name
# Shopper_1  49ers Team Store               2.0  2.0  2.00  2.0         7.0
#            BOSS                           1.0  1.0  1.00  1.0         1.0
#            Bath & Body Works              3.0  3.0  3.00  3.0         1.0
#            Bespoke Events                 4.0  4.0  4.00  4.0         2.0
#            Bloomingdale's                 0.0  1.0  2.00  4.0        64.0
#            Bristol Farms                  0.0  0.0  0.00  0.0         1.0
#            Club Monaco Women              1.0  1.0  1.00  1.0         3.0
#            Cotton On                      2.0  2.0  2.00  2.0        14.0
#            H&M                            3.0  3.0  3.00  3.0         9.0
#            H&M Man                        2.0  2.0  2.00  2.0         4.0
#            Haagen Dazs                    0.0  0.0  0.00  0.0         2.0
#            House of Hoops by Foot Locker  3.0  3.0  3.00  3.0         1.0
#            Kay Jewelers                   3.0  3.0  3.00  3.0         1.0
#            PacSun                         0.0  0.0  0.00  0.0         3.0
#            ProActiv Solutions             0.0  0.0  0.00  0.0        30.0
#            RED Valentino                  1.0  1.0  1.00  1.0         1.0
#            Sarku Japan                    0.0  0.0  0.00  0.0         2.0
#            Solstice                       3.0  3.0  3.00  3.0        17.0
#            Swarovski                      1.0  1.0  1.00  1.0        14.0
#            TAP 415                        4.0  4.0  4.00  4.0         8.0
#            The Walking Company            3.0  3.0  3.00  3.0         2.0
#            abercrombie kids               3.0  3.0  3.00  3.0         2.0
# Shopper_10 49ers Team Store               2.0  2.0  2.00  2.0         2.0
#            Auntie Anne's Pretzels         2.0  2.0  2.00  2.0         1.0
#            Bespoke Events                 4.0  4.0  4.00  4.0         4.0
#            Bloomingdale's                 1.0  1.0  1.75  4.0         4.0
#            Brighton Collectibles          1.0  1.0  1.00  1.0         5.0
#            Bristol Farms                  0.0  0.0  0.00  0.0         1.0
#            Camper                         2.0  2.0  2.00  2.0         2.0
#            Chipotle                       0.0  0.0  0.00  0.0         1.0
# ...                                       ...  ...   ...  ...         ...
# Shopper_98 Swarovski                      1.0  1.0  1.00  1.0        49.0
#            TAP 415                        4.0  4.0  4.00  4.0         1.0
# Shopper_99 49ers Team Store               2.0  2.0  2.00  2.0         3.0
#            BOSS                           1.0  1.0  1.00  1.0         3.0
#            Bath & Body Works              3.0  3.0  3.00  3.0         1.0
#            Bespoke Events                 4.0  4.0  4.00  4.0         9.0
#            Bloomingdale's                 2.0  4.0  4.00  4.0         5.0
#            Brighton Collectibles          1.0  1.0  1.00  1.0         3.0
#            Bristol Farms                  0.0  0.0  0.00  0.0         2.0
#            Camper                         2.0  2.0  2.00  2.0         5.0
#            Club Monaco Women              1.0  1.0  1.00  1.0         3.0
#            Cotton On                      2.0  2.0  2.00  2.0        26.0
#            H&M                            3.0  3.0  3.00  3.0         1.0
#            H&M Man                        2.0  2.0  2.00  2.0         3.0
#            Haagen Dazs                    0.0  0.0  0.00  0.0         3.0
#            Janie And Jack                 1.0  1.0  1.00  1.0         2.0
#            Kay Jewelers                   3.0  3.0  3.00  3.0         1.0
#            L'Occitane en Provence         1.0  1.0  1.00  1.0         3.0
#            Lady Foot Locker               2.0  2.0  2.00  2.0         4.0
#            Lids                           3.0  3.0  3.00  3.0         1.0
#            M.Y. China                     4.0  4.0  4.00  4.0         1.0
#            ProActiv Solutions             0.0  0.0  0.00  0.0        51.0
#            Sarku Japan                    0.0  0.0  0.00  0.0         1.0
#            Solstice                       3.0  3.0  3.00  3.0         7.0
#            Sunglass Hut                   0.0  0.0  0.00  0.0         1.0
#            Swarovski                      1.0  1.0  1.00  1.0        28.0
#            Swatch                         1.0  1.0  1.00  1.0         2.0
#            TAP 415                        4.0  4.0  4.00  4.0        18.0
#            The Art of Shaving             1.0  1.0  1.00  1.0         2.0
#            abercrombie kids               3.0  3.0  3.00  3.0         1.0
#
#                                                     ...       latitude  \
#                                            mean     ...            75%
# Shopper_ID Store_Name                               ...
# Shopper_1  49ers Team Store                 0.0     ...      34.981382
#            BOSS                            14.0     ...      35.539867
#            Bath & Body Works               16.0     ...      35.664542
#            Bespoke Events                  19.0     ...      35.733657
#            Bloomingdale's                  20.0     ...      33.585830
#            Bristol Farms                   23.0     ...      35.240591
#            Club Monaco Women               39.0     ...      34.756492
#            Cotton On                       43.0     ...      37.784076
#            H&M                             62.0     ...      35.399525
#            H&M Man                         63.0     ...      35.692423
#            Haagen Dazs                     64.0     ...      35.659368
#            House of Hoops by Foot Locker   67.0     ...      34.635392
#            Kay Jewelers                    73.0     ...      37.716263
#            PacSun                          99.0     ...      35.481179
#            ProActiv Solutions             108.0     ...      37.784109
#            RED Valentino                  109.0     ...      37.716259
#            Sarku Japan                    116.0     ...      34.349156
#            Solstice                       119.0     ...      37.784077
#            Swarovski                      128.0     ...      37.784095
#            TAP 415                        131.0     ...      37.784114
#            The Walking Company            135.0     ...      35.851335
#            abercrombie kids               149.0     ...      34.349175
# Shopper_10 49ers Team Store                 0.0     ...      35.153643
#            Auntie Anne's Pretzels          11.0     ...      37.239922
#            Bespoke Events                  19.0     ...      35.127255
#            Bloomingdale's                  20.0     ...      35.184860
#            Brighton Collectibles           22.0     ...      37.031481
#            Bristol Farms                   23.0     ...      36.665839
#            Camper                          31.0     ...      36.874803
#            Chipotle                        35.0     ...      34.100234
# ...                                         ...     ...            ...
# Shopper_98 Swarovski                      128.0     ...      37.784067
#            TAP 415                        131.0     ...      37.784223
# Shopper_99 49ers Team Store                 0.0     ...      35.331742
#            BOSS                            14.0     ...      35.399781
#            Bath & Body Works               16.0     ...      36.550032
#            Bespoke Events                  19.0     ...      35.153084
#            Bloomingdale's                  20.0     ...      33.987472
#            Brighton Collectibles           22.0     ...      36.656019
#            Bristol Farms                   23.0     ...      36.706976
#            Camper                          31.0     ...      36.716910
#            Club Monaco Women               39.0     ...      34.759970
#            Cotton On                       43.0     ...      37.784017
#            H&M                             62.0     ...      35.539964
#            H&M Man                         63.0     ...      35.776313
#            Haagen Dazs                     64.0     ...      35.876756
#            Janie And Jack                  70.0     ...      35.919820
#            Kay Jewelers                    73.0     ...      37.596348
#            L'Occitane en Provence          76.0     ...      36.226282
#            Lady Foot Locker                78.0     ...      36.006933
#            Lids                            79.0     ...      36.194433
#            M.Y. China                      83.0     ...      36.049928
#            ProActiv Solutions             108.0     ...      37.784212
#            Sarku Japan                    116.0     ...      34.401416
#            Solstice                       119.0     ...      37.784019
#            Sunglass Hut                   125.0     ...      36.125510
#            Swarovski                      128.0     ...      37.784346
#            Swatch                         129.0     ...      37.582725
#            TAP 415                        131.0     ...      37.784389
#            The Art of Shaving             133.0     ...      36.336388
#            abercrombie kids               149.0     ...      34.218488
#
#                                                     longitude              \
#                                                 max     count        mean
# Shopper_ID Store_Name
# Shopper_1  49ers Team Store               35.399507       7.0 -112.735348
#            BOSS                           35.539867       1.0 -115.187304
#            Bath & Body Works              35.664542       1.0 -115.588398
#            Bespoke Events                 35.756717       2.0 -115.759376
#            Bloomingdale's                 35.664494      64.0 -100.041579
#            Bristol Farms                  35.240591       1.0 -114.224934
#            Club Monaco Women              34.877600       3.0 -112.158942
#            Cotton On                      37.784150      14.0 -122.404261
#            H&M                            35.539812       9.0 -114.049064
#            H&M Man                        35.776100       4.0 -115.482491
#            Haagen Dazs                    35.664467       2.0 -115.579555
#            House of Hoops by Foot Locker  34.635392       1.0 -112.206476
#            Kay Jewelers                   37.716263       1.0 -122.187249
#            PacSun                         35.539799       3.0 -114.893503
#            ProActiv Solutions             37.784263      30.0 -122.402133
#            RED Valentino                  37.716259       1.0 -122.187237
#            Sarku Japan                    34.349161       2.0 -111.279068
#            Solstice                       37.784121      17.0 -122.404881
#            Swarovski                      37.784128      14.0 -122.403778
#            TAP 415                        37.784158       8.0 -122.393541
#            The Walking Company            35.876436       2.0 -116.109035
#            abercrombie kids               34.349176       2.0 -111.279110
# Shopper_10 49ers Team Store               35.375902       2.0 -113.165187
#            Auntie Anne's Pretzels         37.239922       1.0 -120.642571
#            Bespoke Events                 35.135766       4.0 -113.271800
#            Bloomingdale's                 35.203609       4.0 -112.314990
#            Brighton Collectibles          37.039586       5.0 -119.646636
#            Bristol Farms                  36.665839       1.0 -118.782953
#            Camper                         37.067269       2.0 -118.836670
#            Chipotle                       34.100234       1.0 -110.472823
# ...                                             ...       ...         ...
# Shopper_98 Swarovski                      37.784564      49.0 -122.407030
#            TAP 415                        37.784223       1.0 -122.406595
# Shopper_99 49ers Team Store               35.422896       3.0 -113.455975
#            BOSS                           35.399860       3.0 -114.736085
#            Bath & Body Works              36.550032       1.0 -118.408601
#            Bespoke Events                 35.540035       9.0 -113.225671
#            Bloomingdale's                 35.664664       5.0 -110.750704
#            Brighton Collectibles          36.711757       3.0 -118.634512
#            Bristol Farms                  36.711092       2.0 -118.903739
#            Camper                         36.731214       5.0 -118.872381
#            Club Monaco Women              34.878280       3.0 -112.330853
#            Cotton On                      37.784615      26.0 -122.319116
#            H&M                            35.539964       1.0 -115.187357
#            H&M Man                        35.776410       3.0 -115.827529
#            Haagen Dazs                    35.876831       3.0 -116.042914
#            Janie And Jack                 35.967674       2.0 -116.254680
#            Kay Jewelers                   37.596348       1.0 -121.799024
#            L'Occitane en Provence         36.257929       3.0 -117.200727
#            Lady Foot Locker               36.125315       4.0 -116.543429
#            Lids                           36.194433       1.0 -117.293123
#            M.Y. China                     36.049928       1.0 -116.828233
#            ProActiv Solutions             37.785072      51.0 -122.381705
#            Sarku Japan                    34.401416       1.0 -111.466124
#            Solstice                       37.784026       7.0 -122.400953
#            Sunglass Hut                   36.125510       1.0 -117.070583
#            Swarovski                      37.785318      28.0 -122.401428
#            Swatch                         37.583199       2.0 -121.753377
#            TAP 415                        37.784623      18.0 -122.307073
#            The Art of Shaving             36.336577       2.0 -117.715760
#            abercrombie kids               34.218488       1.0 -110.902210
#
#                                                                              \
#                                                 std         min         25%
# Shopper_ID Store_Name
# Shopper_1  49ers Team Store                1.259467 -114.736382 -113.327500
#            BOSS                                 NaN -115.187304 -115.187304
#            Bath & Body Works                    NaN -115.588398 -115.588398
#            Bespoke Events                  0.241615 -115.930223 -115.844800
#            Bloomingdale's                 16.522958 -115.588692 -108.806248
#            Bristol Farms                        NaN -114.224934 -114.224934
#            Club Monaco Women               0.856980 -112.991140 -112.598832
#            Cotton On                       0.007147 -122.407213 -122.407141
#            H&M                             0.778325 -115.187564 -114.736331
#            H&M Man                         0.360678 -115.947265 -115.678128
#            Haagen Dazs                     0.012921 -115.588692 -115.584123
#            House of Hoops by Foot Locker        NaN -112.206476 -112.206476
#            Kay Jewelers                         NaN -122.187249 -122.187249
#            PacSun                          0.254887 -115.187584 -114.972141
#            ProActiv Solutions              0.015500 -122.407302 -122.407162
#            RED Valentino                        NaN -122.187237 -122.187237
#            Sarku Japan                     0.000148 -111.279173 -111.279120
#            Solstice                        0.006154 -122.407207 -122.407150
#            Swarovski                       0.008425 -122.407198 -122.407127
#            TAP 415                         0.028797 -122.407049 -122.406821
#            The Walking Company             0.228386 -116.270529 -116.189782
#            abercrombie kids                0.000027 -111.279129 -111.279120
# Shopper_10 49ers Team Store                2.036779 -114.605407 -113.885297
#            Auntie Anne's Pretzels               NaN -120.642571 -120.642571
#            Bespoke Events                  0.972777 -113.827394 -113.799833
#            Bloomingdale's                  3.151391 -114.047399 -113.986064
#            Brighton Collectibles           0.323971 -119.993700 -119.967906
#            Bristol Farms                        NaN -118.782953 -118.782953
#            Camper                          1.763762 -120.083838 -119.460254
#            Chipotle                             NaN -110.472823 -110.472823
# ...                                             ...         ...         ...
# Shopper_98 Swarovski                       0.000146 -122.407262 -122.407113
#            TAP 415                              NaN -122.406595 -122.406595
# Shopper_99 49ers Team Store                1.811458 -114.756099 -114.490520
#            BOSS                            0.000260 -114.736313 -114.736226
#            Bath & Body Works                    NaN -118.408601 -118.408601
#            Bespoke Events                  1.222782 -115.187127 -113.942530
#            Bloomingdale's                  2.750469 -115.588414 -110.149677
#            Brighton Collectibles           0.272048 -118.932571 -118.751982
#            Bristol Farms                   0.037729 -118.930418 -118.917079
#            Camper                          0.106339 -118.996073 -118.949556
#            Club Monaco Women               0.632001 -112.992201 -112.629783
#            Cotton On                       0.208842 -122.407265 -122.407103
#            H&M                                  NaN -115.187357 -115.187357
#            H&M Man                         0.207177 -115.947290 -115.947143
#            Haagen Dazs                     0.393422 -116.270122 -116.270056
#            Janie And Jack                  0.434915 -116.562212 -116.408446
#            Kay Jewelers                         NaN -121.799024 -121.799024
#            L'Occitane en Provence          0.350654 -117.496074 -117.394497
#            Lady Foot Locker                0.377590 -117.070787 -116.689521
#            Lids                                 NaN -117.293123 -117.293123
#            M.Y. China                           NaN -116.828233 -116.828233
#            ProActiv Solutions              0.100355 -122.409203 -122.407054
#            Sarku Japan                          NaN -111.466124 -111.466124
#            Solstice                        0.011070 -122.407110 -122.407097
#            Sunglass Hut                         NaN -117.070583 -117.070583
#            Swarovski                       0.007984 -122.409686 -122.406787
#            Swatch                          0.004345 -121.756450 -121.754913
#            TAP 415                         0.360206 -122.406745 -122.406516
#            The Art of Shaving              0.001732 -117.716985 -117.716373
#            abercrombie kids                     NaN -110.902210 -110.902210
#
#
#                                                  50%         75%         max
# Shopper_ID Store_Name
# Shopper_1  49ers Team Store              -112.991175 -111.742864 -111.279150
#            BOSS                          -115.187304 -115.187304 -115.187304
#            Bath & Body Works             -115.588398 -115.588398 -115.588398
#            Bespoke Events                -115.759376 -115.673952 -115.588529
#            Bloomingdale's                -104.920363 -101.542209  -51.038836
#            Bristol Farms                 -114.224934 -114.224934 -114.224934
#            Club Monaco Women             -112.206523 -111.742843 -111.279163
#            Cotton On                     -122.407099 -122.406918 -122.386801
#            H&M                           -114.224980 -113.663578 -112.991140
#            H&M Man                       -115.397557 -115.201920 -115.187586
#            Haagen Dazs                   -115.579555 -115.574987 -115.570418
#            House of Hoops by Foot Locker -112.206476 -112.206476 -112.206476
#            Kay Jewelers                  -122.187249 -122.187249 -122.187249
#            PacSun                        -114.756697 -114.746463 -114.736228
#            ProActiv Solutions            -122.406884 -122.406457 -122.341798
#            RED Valentino                 -122.187237 -122.187237 -122.187237
#            Sarku Japan                   -111.279068 -111.279016 -111.278963
#            Solstice                      -122.407085 -122.407039 -122.388008
#            Swarovski                     -122.407086 -122.406999 -122.383891
#            TAP 415                       -122.406719 -122.400416 -122.325626
#            The Walking Company           -116.109035 -116.028289 -115.947542
#            abercrombie kids              -111.279110 -111.279101 -111.279091
# Shopper_10 49ers Team Store              -113.165187 -112.445077 -111.724967
#            Auntie Anne's Pretzels        -120.642571 -120.642571 -120.642571
#            Bespoke Events                -113.721387 -113.193354 -111.817032
#            Bloomingdale's                -113.808873 -112.137800 -107.594816
#            Brighton Collectibles         -119.599567 -119.357911 -119.314095
#            Bristol Farms                 -118.782953 -118.782953 -118.782953
#            Camper                        -118.836670 -118.213086 -117.589502
#            Chipotle                      -110.472823 -110.472823 -110.472823
# ...                                              ...         ...         ...
# Shopper_98 Swarovski                     -122.407053 -122.407008 -122.406374
#            TAP 415                       -122.406595 -122.406595 -122.406595
# Shopper_99 49ers Team Store              -114.224940 -112.805913 -111.386886
#            BOSS                          -114.736139 -114.735970 -114.735801
#            Bath & Body Works             -118.408601 -118.408601 -118.408601
#            Bespoke Events                -112.966029 -112.965748 -110.960084
#            Bloomingdale's                -109.740750 -109.504599 -108.770082
#            Brighton Collectibles         -118.571393 -118.485483 -118.399573
#            Bristol Farms                 -118.903739 -118.890400 -118.877061
#            Camper                        -118.870026 -118.819317 -118.726933
#            Club Monaco Women             -112.267364 -112.000178 -111.732993
#            Cotton On                     -122.407086 -122.406403 -121.798387
#            H&M                           -115.187357 -115.187357 -115.187357
#            H&M Man                       -115.946996 -115.767649 -115.588303
#            Haagen Dazs                   -116.269989 -115.929309 -115.588629
#            Janie And Jack                -116.254680 -116.100914 -115.947148
#            Kay Jewelers                  -121.799024 -121.799024 -121.799024
#            L'Occitane en Provence        -117.292919 -117.053053 -116.813187
#            Lady Foot Locker              -116.416444 -116.270353 -116.270043
#            Lids                          -117.293123 -117.293123 -117.293123
#            M.Y. China                    -116.828233 -116.828233 -116.828233
#            ProActiv Solutions            -122.407016 -122.406637 -121.799954
#            Sarku Japan                   -111.466124 -111.466124 -111.466124
#            Solstice                      -122.407072 -122.399447 -122.379400
#            Sunglass Hut                  -117.070583 -117.070583 -117.070583
#            Swarovski                     -122.406541 -122.395289 -122.379390
#            Swatch                        -121.753377 -121.751841 -121.750305
#            TAP 415                       -122.391547 -122.380519 -120.865104
#            The Art of Shaving            -117.715760 -117.715148 -117.714535
#            abercrombie kids              -110.902210 -110.902210 -110.902210
#
# [10121 rows x 32 columns]

# %%
from scipy import stats
df_freq = pinginfo.groupby(by='Shopper_ID').Store_Name.apply(stats.mode)
# Out:
# C:\Users\welcome\Anaconda2\lib\site-packages\scipy\stats\stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %%
df_freq
# Out:
# Shopper_ID
# Shopper_1            ([Bloomingdale's], [64])
# Shopper_10                  ([TAP 415], [80])
# Shopper_100     ([ProActiv Solutions ], [58])
# Shopper_101               ([Swarovski], [53])
# Shopper_102                ([TAP 415], [125])
# Shopper_103               ([Cotton On], [52])
# Shopper_104     ([ProActiv Solutions ], [71])
# Shopper_105     ([ProActiv Solutions ], [61])
# Shopper_106     ([ProActiv Solutions ], [63])
# Shopper_107     ([ProActiv Solutions ], [61])
# Shopper_108    ([ProActiv Solutions ], [105])
# Shopper_109          ([Bloomingdale's], [56])
# Shopper_11      ([ProActiv Solutions ], [72])
# Shopper_110     ([ProActiv Solutions ], [51])
# Shopper_111               ([Swarovski], [56])
# Shopper_112     ([ProActiv Solutions ], [77])
# Shopper_113     ([ProActiv Solutions ], [97])
# Shopper_114                 ([TAP 415], [90])
# Shopper_115               ([Cotton On], [55])
# Shopper_116                ([TAP 415], [167])
# Shopper_117    ([ProActiv Solutions ], [133])
# Shopper_118               ([Cotton On], [45])
# Shopper_119              ([Swarovski], [119])
# Shopper_12      ([ProActiv Solutions ], [32])
# Shopper_120               ([Swarovski], [59])
# Shopper_121     ([ProActiv Solutions ], [44])
# Shopper_122                 ([TAP 415], [49])
# Shopper_123               ([Swarovski], [72])
# Shopper_124     ([ProActiv Solutions ], [75])
# Shopper_125               ([Cotton On], [41])
#                             ...
# Shopper_72                  ([TAP 415], [59])
# Shopper_73      ([ProActiv Solutions ], [51])
# Shopper_74      ([ProActiv Solutions ], [60])
# Shopper_75                ([Swarovski], [56])
# Shopper_76     ([ProActiv Solutions ], [116])
# Shopper_77                  ([TAP 415], [41])
# Shopper_78                ([Cotton On], [54])
# Shopper_79                ([Cotton On], [55])
# Shopper_8                 ([Swarovski], [57])
# Shopper_80      ([ProActiv Solutions ], [71])
# Shopper_81      ([ProActiv Solutions ], [46])
# Shopper_82                  ([TAP 415], [56])
# Shopper_83      ([ProActiv Solutions ], [58])
# Shopper_84                  ([TAP 415], [86])
# Shopper_85     ([ProActiv Solutions ], [107])
# Shopper_86      ([ProActiv Solutions ], [57])
# Shopper_87                  ([TAP 415], [38])
# Shopper_88                ([Swarovski], [45])
# Shopper_89      ([ProActiv Solutions ], [76])
# Shopper_9       ([ProActiv Solutions ], [73])
# Shopper_90                ([Swarovski], [67])
# Shopper_91      ([ProActiv Solutions ], [77])
# Shopper_92      ([ProActiv Solutions ], [71])
# Shopper_93                  ([TAP 415], [51])
# Shopper_94                ([Cotton On], [57])
# Shopper_95                ([Swarovski], [86])
# Shopper_96                 ([Solstice], [38])
# Shopper_97           ([Bloomingdale's], [42])
# Shopper_98      ([ProActiv Solutions ], [66])
# Shopper_99      ([ProActiv Solutions ], [51])
# Name: Store_Name, Length: 567, dtype: object

# %%
df_freq= df_freq.to_frame()

# %%
df_freq.iloc[1,:]
# Out:
# Store_Name    ([TAP 415], [80])
# Name: Shopper_10, dtype: object

# %%
mostvisitedshoplist= []
for shop in df_freq['Store_Name']:
    mostvisitedshoplist.append(shop[0][0])

# %%
mostvisitedshop_array= np.array(mostvisitedshoplist)
mostvisitedshop_array
# Out:
# array([u"Bloomingdale's", u'TAP 415', u'ProActiv Solutions ',
#        u'Swarovski', u'TAP 415', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'Cotton On', u'TAP 415', u'ProActiv Solutions ', u'Cotton On',
#        u'Swarovski', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u"Bloomingdale's",
#        u"Bloomingdale's", u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'Cotton On', u'ProActiv Solutions ', u'TAP 415',
#        u'TAP 415', u'Cotton On', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'Swarovski',
#        u"Bloomingdale's", u'TAP 415', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Solstice', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'Swarovski', u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'Swarovski', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'TAP 415', u'Swarovski',
#        u'Swarovski', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'Swarovski', u'Cotton On', u'ProActiv Solutions ',
#        u"Bloomingdale's", u"Bloomingdale's", u"Bloomingdale's",
#        u'Swarovski', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'Swarovski', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'Swarovski', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'TAP 415',
#        u'Cotton On', u'ProActiv Solutions ', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'Cotton On',
#        u'Swarovski', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'Swarovski', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'TAP 415', u'TAP 415', u'ProActiv Solutions ',
#        u'Cotton On', u'Cotton On', u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'TAP 415', u'Cotton On', u'ProActiv Solutions ', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Swarovski', u'Solstice',
#        u"Bloomingdale's", u'Cotton On', u'Cotton On', u'TAP 415',
#        u'Solstice', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'Cotton On', u'TAP 415', u'Swarovski', u'Swarovski',
#        u'Solstice', u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Solstice', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On', u'Cotton On',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u'ProActiv Solutions ', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'Swarovski', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'Swarovski', u'Solstice', u'TAP 415', u'ProActiv Solutions ',
#        u'Solstice', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'Cotton On', u'Swarovski', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'Solstice',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Cotton On',
#        u'Swarovski', u"Bloomingdale's", u'Swarovski', u'Swarovski',
#        u'Swarovski', u'Cotton On', u'Cotton On', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'Marbles: The Brain Store',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'Solstice', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'Swarovski', u'Swarovski', u'Solstice', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Solstice', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'TAP 415', u'Swarovski', u'TAP 415',
#        u'TAP 415', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Solstice', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'TAP 415', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Cotton On',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'Swarovski', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'TAP 415', u'Cotton On',
#        u"Bloomingdale's", u'Swarovski', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Solstice', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'Cotton On', u'Cotton On', u'TAP 415', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'Swarovski', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'TAP 415', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'TAP 415',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'TAP 415', u'Cotton On',
#        u'Cotton On', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'Cotton On', u'Swarovski',
#        u'Solstice', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'ProActiv Solutions '], dtype='<U24')

# %%
mostvisitedshop_array.astype(object)
# Out:
# array([u"Bloomingdale's", u'TAP 415', u'ProActiv Solutions ',
#        u'Swarovski', u'TAP 415', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'Cotton On', u'TAP 415', u'ProActiv Solutions ', u'Cotton On',
#        u'Swarovski', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u"Bloomingdale's",
#        u"Bloomingdale's", u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'Cotton On', u'ProActiv Solutions ', u'TAP 415',
#        u'TAP 415', u'Cotton On', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'Swarovski',
#        u"Bloomingdale's", u'TAP 415', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Solstice', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'Swarovski', u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'Swarovski', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'TAP 415', u'Swarovski',
#        u'Swarovski', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'Swarovski', u'Cotton On', u'ProActiv Solutions ',
#        u"Bloomingdale's", u"Bloomingdale's", u"Bloomingdale's",
#        u'Swarovski', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'Swarovski', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'Swarovski', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'TAP 415',
#        u'Cotton On', u'ProActiv Solutions ', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'Cotton On',
#        u'Swarovski', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'Swarovski', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'TAP 415', u'TAP 415', u'ProActiv Solutions ',
#        u'Cotton On', u'Cotton On', u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'TAP 415', u'Cotton On', u'ProActiv Solutions ', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Swarovski', u'Solstice',
#        u"Bloomingdale's", u'Cotton On', u'Cotton On', u'TAP 415',
#        u'Solstice', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'Cotton On', u'TAP 415', u'Swarovski', u'Swarovski',
#        u'Solstice', u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Solstice', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Cotton On',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On', u'Cotton On',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On',
#        u'ProActiv Solutions ', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'Swarovski', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'Swarovski', u'Solstice', u'TAP 415', u'ProActiv Solutions ',
#        u'Solstice', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'Cotton On', u'Swarovski', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'Solstice',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Cotton On',
#        u'Swarovski', u"Bloomingdale's", u'Swarovski', u'Swarovski',
#        u'Swarovski', u'Cotton On', u'Cotton On', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'Marbles: The Brain Store',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'Solstice', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'TAP 415',
#        u'Swarovski', u'Swarovski', u'Solstice', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Solstice', u'Cotton On', u'TAP 415',
#        u'ProActiv Solutions ', u'TAP 415', u'Swarovski', u'TAP 415',
#        u'TAP 415', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Solstice', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'TAP 415', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u'Cotton On',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'Swarovski', u'TAP 415',
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'TAP 415', u'Cotton On',
#        u"Bloomingdale's", u'Swarovski', u'ProActiv Solutions ',
#        u'Cotton On', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Solstice', u'ProActiv Solutions ', u'Swarovski',
#        u'ProActiv Solutions ', u'ProActiv Solutions ', u"Bloomingdale's",
#        u'Cotton On', u'Cotton On', u'TAP 415', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'Swarovski', u'ProActiv Solutions ',
#        u"Bloomingdale's", u'ProActiv Solutions ', u'Solstice',
#        u'ProActiv Solutions ', u'TAP 415', u'Cotton On', u'Swarovski',
#        u'ProActiv Solutions ', u'TAP 415', u'TAP 415',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u"Bloomingdale's", u'Swarovski',
#        u'ProActiv Solutions ', u'Cotton On', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Cotton On', u"Bloomingdale's",
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'Swarovski', u'ProActiv Solutions ', u'TAP 415', u'Cotton On',
#        u'Cotton On', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'ProActiv Solutions ',
#        u'TAP 415', u'ProActiv Solutions ', u'ProActiv Solutions ',
#        u'TAP 415', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'Swarovski', u'ProActiv Solutions ',
#        u'ProActiv Solutions ', u'TAP 415', u'Cotton On', u'Swarovski',
#        u'Solstice', u"Bloomingdale's", u'ProActiv Solutions ',
#        u'ProActiv Solutions '], dtype=object)

# %%
#df_freq = df_freq.to_frame().reset_index()

# %%
df_freq['New_Store']= mostvisitedshop_array
df_freq.head()
# Out:
#                                 Store_Name            New_Store
# Shopper_ID
# Shopper_1         ([Bloomingdale's], [64])       Bloomingdale's
# Shopper_10               ([TAP 415], [80])              TAP 415
# Shopper_100  ([ProActiv Solutions ], [58])  ProActiv Solutions
# Shopper_101            ([Swarovski], [53])            Swarovski
# Shopper_102             ([TAP 415], [125])              TAP 415

# %%
df_freq.to_csv(r"C:\Users\welcome\Desktop\exl__rf.csv")

# %%
df_freq
# Out:
#                                  Store_Name            New_Store
# Shopper_ID
# Shopper_1          ([Bloomingdale's], [64])       Bloomingdale's
# Shopper_10                ([TAP 415], [80])              TAP 415
# Shopper_100   ([ProActiv Solutions ], [58])  ProActiv Solutions
# Shopper_101             ([Swarovski], [53])            Swarovski
# Shopper_102              ([TAP 415], [125])              TAP 415
# Shopper_103             ([Cotton On], [52])            Cotton On
# Shopper_104   ([ProActiv Solutions ], [71])  ProActiv Solutions
# Shopper_105   ([ProActiv Solutions ], [61])  ProActiv Solutions
# Shopper_106   ([ProActiv Solutions ], [63])  ProActiv Solutions
# Shopper_107   ([ProActiv Solutions ], [61])  ProActiv Solutions
# Shopper_108  ([ProActiv Solutions ], [105])  ProActiv Solutions
# Shopper_109        ([Bloomingdale's], [56])       Bloomingdale's
# Shopper_11    ([ProActiv Solutions ], [72])  ProActiv Solutions
# Shopper_110   ([ProActiv Solutions ], [51])  ProActiv Solutions
# Shopper_111             ([Swarovski], [56])            Swarovski
# Shopper_112   ([ProActiv Solutions ], [77])  ProActiv Solutions
# Shopper_113   ([ProActiv Solutions ], [97])  ProActiv Solutions
# Shopper_114               ([TAP 415], [90])              TAP 415
# Shopper_115             ([Cotton On], [55])            Cotton On
# Shopper_116              ([TAP 415], [167])              TAP 415
# Shopper_117  ([ProActiv Solutions ], [133])  ProActiv Solutions
# Shopper_118             ([Cotton On], [45])            Cotton On
# Shopper_119            ([Swarovski], [119])            Swarovski
# Shopper_12    ([ProActiv Solutions ], [32])  ProActiv Solutions
# Shopper_120             ([Swarovski], [59])            Swarovski
# Shopper_121   ([ProActiv Solutions ], [44])  ProActiv Solutions
# Shopper_122               ([TAP 415], [49])              TAP 415
# Shopper_123             ([Swarovski], [72])            Swarovski
# Shopper_124   ([ProActiv Solutions ], [75])  ProActiv Solutions
# Shopper_125             ([Cotton On], [41])            Cotton On
# ...                                     ...                  ...
# Shopper_72                ([TAP 415], [59])              TAP 415
# Shopper_73    ([ProActiv Solutions ], [51])  ProActiv Solutions
# Shopper_74    ([ProActiv Solutions ], [60])  ProActiv Solutions
# Shopper_75              ([Swarovski], [56])            Swarovski
# Shopper_76   ([ProActiv Solutions ], [116])  ProActiv Solutions
# Shopper_77                ([TAP 415], [41])              TAP 415
# Shopper_78              ([Cotton On], [54])            Cotton On
# Shopper_79              ([Cotton On], [55])            Cotton On
# Shopper_8               ([Swarovski], [57])            Swarovski
# Shopper_80    ([ProActiv Solutions ], [71])  ProActiv Solutions
# Shopper_81    ([ProActiv Solutions ], [46])  ProActiv Solutions
# Shopper_82                ([TAP 415], [56])              TAP 415
# Shopper_83    ([ProActiv Solutions ], [58])  ProActiv Solutions
# Shopper_84                ([TAP 415], [86])              TAP 415
# Shopper_85   ([ProActiv Solutions ], [107])  ProActiv Solutions
# Shopper_86    ([ProActiv Solutions ], [57])  ProActiv Solutions
# Shopper_87                ([TAP 415], [38])              TAP 415
# Shopper_88              ([Swarovski], [45])            Swarovski
# Shopper_89    ([ProActiv Solutions ], [76])  ProActiv Solutions
# Shopper_9     ([ProActiv Solutions ], [73])  ProActiv Solutions
# Shopper_90              ([Swarovski], [67])            Swarovski
# Shopper_91    ([ProActiv Solutions ], [77])  ProActiv Solutions
# Shopper_92    ([ProActiv Solutions ], [71])  ProActiv Solutions
# Shopper_93                ([TAP 415], [51])              TAP 415
# Shopper_94              ([Cotton On], [57])            Cotton On
# Shopper_95              ([Swarovski], [86])            Swarovski
# Shopper_96               ([Solstice], [38])             Solstice
# Shopper_97         ([Bloomingdale's], [42])       Bloomingdale's
# Shopper_98    ([ProActiv Solutions ], [66])  ProActiv Solutions
# Shopper_99    ([ProActiv Solutions ], [51])  ProActiv Solutions
#
# [567 rows x 2 columns]

# %%
df_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 567 entries, Shopper_1 to Shopper_99
# Data columns (total 2 columns):
# Store_Name    567 non-null object
# New_Store     567 non-null object
# dtypes: object(2)
# memory usage: 33.3+ KB

# %%
#df_freq.sort_values(['Shopper_ID'], axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

# %%
#df_freq.to_csv(r"C:\Users\welcome\Desktop\exl__rf.csv", index=False)

# %%
df_freq2=pinginfo.pivot_table(values='Store_Name', columns='Shopper_ID', aggfunc=stats.mode)

# %%
df_freq2
# Out:
# Shopper_ID                 Shopper_1         Shopper_10  \
# Store_Name  ([Bloomingdale's], [64])  ([TAP 415], [80])
#
# Shopper_ID                    Shopper_100          Shopper_101  \
# Store_Name  ([ProActiv Solutions ], [58])  ([Swarovski], [53])
#
# Shopper_ID         Shopper_102          Shopper_103  \
# Store_Name  ([TAP 415], [125])  ([Cotton On], [52])
#
# Shopper_ID                    Shopper_104                    Shopper_105  \
# Store_Name  ([ProActiv Solutions ], [71])  ([ProActiv Solutions ], [61])
#
# Shopper_ID                    Shopper_106                    Shopper_107  \
# Store_Name  ([ProActiv Solutions ], [63])  ([ProActiv Solutions ], [61])
#
# Shopper_ID              ...                         Shopper_90  \
# Store_Name              ...                ([Swarovski], [67])
#
# Shopper_ID                     Shopper_91                     Shopper_92  \
# Store_Name  ([ProActiv Solutions ], [77])  ([ProActiv Solutions ], [71])
#
# Shopper_ID         Shopper_93           Shopper_94           Shopper_95  \
# Store_Name  ([TAP 415], [51])  ([Cotton On], [57])  ([Swarovski], [86])
#
# Shopper_ID          Shopper_96                Shopper_97  \
# Store_Name  ([Solstice], [38])  ([Bloomingdale's], [42])
#
# Shopper_ID                     Shopper_98                     Shopper_99
# Store_Name  ([ProActiv Solutions ], [66])  ([ProActiv Solutions ], [51])
#
# [1 rows x 567 columns]

# %%
df_freq2.to_csv(r"C:\Users\welcome\Desktop\exl_final2.csv", index=False)

# %%
#SVM TRAINING AND FITTING:
from sklearn.svm import SVC
for kernel in ('linear', 'poly', 'rbf'):
    clf = svm.SVC(kernel=kernel, gamma=2)
    clf.fit(X, y)


# Training data features, skip the first column 'Survived'
train_features = X

# 'Survived' column values
train_target = y

# Fit the model to our training data
clf = clf.fit(train_features, train_target)
score = clf.score(train_features, train_target)
"Mean accuracy of SVM: {0}".format(score)
# Out:
# 'Mean accuracy of SVM: 0.83734939759'

# %%
test_y2 = clf.predict(test_data)

# %%
pinginfo['Store_Index2'] = test_y2

# %%
pinginfo.head(100)
# Out:
#        Shopper_ID  Floor_Index   latitude   longitude  Store_Index  \
# 35181   Shopper_1            3  37.762391 -122.388008          119
# 70238   Shopper_1            0  33.585825 -108.806374           20
# 70264   Shopper_1            0  37.784023 -122.406786          108
# 40491   Shopper_1            2  37.761052 -122.386801           43
# 4777    Shopper_1            3  35.664542 -115.588398           16
# 4776    Shopper_1            0  32.386375 -104.920369           20
# 101158  Shopper_1            1  34.005662 -110.166421           20
# 49054   Shopper_1            0  35.399517 -114.736228           99
# 22621   Shopper_1            1  32.721647 -106.064451           20
# 22620   Shopper_1            0  17.523494  -56.901809           20
# 22619   Shopper_1            2  34.349167 -111.279150            0
# 52049   Shopper_1            3  31.486702 -102.005952           20
# 95887   Shopper_1            1  33.061045 -107.106172           20
# 98815   Shopper_1            0  37.784038 -122.406711          108
# 78061   Shopper_1            1  31.971133 -103.575228           20
# 106999  Shopper_1            0  33.061063 -107.106165           20
# 78035   Shopper_1            0  37.784263 -122.405984          108
# 77973   Shopper_1            3  37.784085 -122.407135          119
# 100499  Shopper_1            3  37.784018 -122.407150          119
# 35762   Shopper_1            3  37.784052 -122.407079          119
# 71239   Shopper_1            3  37.784055 -122.407086          119
# 97924   Shopper_1            0  37.784075 -122.407065          108
# 102120  Shopper_1            0  37.784055 -122.407176          108
# 97101   Shopper_1            2  33.787407 -109.504903           20
# 47032   Shopper_1            0  37.784077 -122.407172          108
# 25665   Shopper_1            0  34.349141 -111.278963          116
# 25664   Shopper_1            3  35.085205 -113.663751           62
# 77426   Shopper_1            2  37.784041 -122.407108           43
# 97946   Shopper_1            1  35.265121 -114.246687           20
# 32914   Shopper_1            0  37.784059 -122.406598          108
# ...           ...          ...        ...         ...          ...
# 418     Shopper_1            1  30.227255  -97.925648           20
# 37372   Shopper_1            0  37.784085 -122.407009          108
# 21770   Shopper_1            0  33.968828 -110.133960           20
# 28495   Shopper_1            2  35.561458 -115.206698           63
# 28513   Shopper_1            1  34.349118 -111.279163           39
# 93921   Shopper_1            2  37.784079 -122.407114           43
# 50871   Shopper_1            1  33.565384 -108.788102           20
# 61183   Shopper_1            0  31.971140 -103.575216           20
# 50835   Shopper_1            3  34.877596 -112.991172           62
# 21547   Shopper_1            3  37.784064 -122.407207          119
# 61182   Shopper_1            4  35.756717 -115.930223           19
# 74866   Shopper_1            1  37.757750 -122.383892          128
# 74855   Shopper_1            2  37.762391 -122.388008           43
# 55291   Shopper_1            2  37.783956 -122.407213           43
# 74843   Shopper_1            3  37.784077 -122.407058          119
# 74806   Shopper_1            0  37.784168 -122.406034          108
# 74805   Shopper_1            1  34.635384 -112.206523           39
# 41665   Shopper_1            1  35.539867 -115.187304           14
# 50625   Shopper_1            0  35.644070 -115.570418           64
# 50624   Shopper_1            3  37.784065 -122.407157          119
# 93848   Shopper_1            1  32.746176 -106.086128           20
# 11819   Shopper_1            2  37.784077 -122.407058           43
# 85044   Shopper_1            0  28.338040  -91.805298           20
# 85045   Shopper_1            3  35.539812 -115.187564           62
# 11637   Shopper_1            0  37.784120 -122.406620          108
# 60944   Shopper_1            0  37.784048 -122.407212          108
# 85061   Shopper_1            2  34.635388 -112.206498            0
# 85080   Shopper_1            1  32.386344 -104.920316           20
# 74419   Shopper_1            1  33.585855 -108.806241           20
# 61181   Shopper_1            1  37.784032 -122.407175          128
#
#                  Store_Name  Store_Index2
# 35181              Solstice            93
# 70238        Bloomingdale's             2
# 70264   ProActiv Solutions             93
# 40491             Cotton On            85
# 4777      Bath & Body Works            43
# 4776         Bloomingdale's            93
# 101158       Bloomingdale's             2
# 49054                PacSun            43
# 22621        Bloomingdale's            43
# 22620        Bloomingdale's             2
# 22619      49ers Team Store            85
# 52049        Bloomingdale's            20
# 95887        Bloomingdale's            20
# 98815   ProActiv Solutions             85
# 78061        Bloomingdale's            20
# 106999       Bloomingdale's            85
# 78035   ProActiv Solutions             85
# 77973              Solstice            20
# 100499             Solstice            93
# 35762              Solstice            22
# 71239              Solstice            93
# 97924   ProActiv Solutions             85
# 102120  ProActiv Solutions             20
# 97101        Bloomingdale's            43
# 47032   ProActiv Solutions             20
# 25665           Sarku Japan           119
# 25664                   H&M            20
# 77426             Cotton On            85
# 97946        Bloomingdale's            20
# 32914   ProActiv Solutions              2
# ...                     ...           ...
# 418          Bloomingdale's            31
# 37372   ProActiv Solutions              2
# 21770        Bloomingdale's            93
# 28495               H&M Man            22
# 28513     Club Monaco Women           119
# 93921             Cotton On             2
# 50871        Bloomingdale's             2
# 61183        Bloomingdale's            85
# 50835                   H&M           119
# 21547              Solstice           119
# 61182        Bespoke Events            20
# 74866             Swarovski            85
# 74855             Cotton On             2
# 55291             Cotton On            85
# 74843              Solstice            77
# 74806   ProActiv Solutions             85
# 74805     Club Monaco Women            20
# 41665                  BOSS            20
# 50625           Haagen Dazs            20
# 50624              Solstice            85
# 93848        Bloomingdale's            43
# 11819             Cotton On            20
# 85044        Bloomingdale's            93
# 85045                   H&M             2
# 11637   ProActiv Solutions              2
# 60944   ProActiv Solutions             85
# 85061      49ers Team Store             2
# 85080        Bloomingdale's            43
# 74419        Bloomingdale's             2
# 61181             Swarovski             2
#
# [100 rows x 7 columns]

# %%
#LOGISTIC REFGRESSION AND PREDICTING:
from sklearn import linear_model
clf= linear_model.LogisticRegression()
train_features = X

train_target = y

# Fit the model to our training data
clf = clf.fit(train_features, train_target)
score = clf.score(train_features, train_target)
"Mean accuracy: {0}".format(score)
# Out:
# 'Mean accuracy: 0.0903614457831'

# %%
clf= neighbors.KNeighborsClassifier()

# %%
train_features = X

train_target = y

# Fit the model to our training data
clf = clf.fit(train_features, train_target)
score = clf.score(train_features, train_target)
"Mean accuracy: {0}".format(score)
# Out:
# 'Mean accuracy: 0.246987951807'

# %%
test_y3 = clf.predict(test_data)

# %%
pinginfo['Store_Index3'] = test_y3

# %%
pinginfo.head(100)
# Out:
#        Shopper_ID  Floor_Index   latitude   longitude  Store_Index  \
# 35181   Shopper_1            3  37.762391 -122.388008          119
# 70238   Shopper_1            0  33.585825 -108.806374           20
# 70264   Shopper_1            0  37.784023 -122.406786          108
# 40491   Shopper_1            2  37.761052 -122.386801           43
# 4777    Shopper_1            3  35.664542 -115.588398           16
# 4776    Shopper_1            0  32.386375 -104.920369           20
# 101158  Shopper_1            1  34.005662 -110.166421           20
# 49054   Shopper_1            0  35.399517 -114.736228           99
# 22621   Shopper_1            1  32.721647 -106.064451           20
# 22620   Shopper_1            0  17.523494  -56.901809           20
# 22619   Shopper_1            2  34.349167 -111.279150            0
# 52049   Shopper_1            3  31.486702 -102.005952           20
# 95887   Shopper_1            1  33.061045 -107.106172           20
# 98815   Shopper_1            0  37.784038 -122.406711          108
# 78061   Shopper_1            1  31.971133 -103.575228           20
# 106999  Shopper_1            0  33.061063 -107.106165           20
# 78035   Shopper_1            0  37.784263 -122.405984          108
# 77973   Shopper_1            3  37.784085 -122.407135          119
# 100499  Shopper_1            3  37.784018 -122.407150          119
# 35762   Shopper_1            3  37.784052 -122.407079          119
# 71239   Shopper_1            3  37.784055 -122.407086          119
# 97924   Shopper_1            0  37.784075 -122.407065          108
# 102120  Shopper_1            0  37.784055 -122.407176          108
# 97101   Shopper_1            2  33.787407 -109.504903           20
# 47032   Shopper_1            0  37.784077 -122.407172          108
# 25665   Shopper_1            0  34.349141 -111.278963          116
# 25664   Shopper_1            3  35.085205 -113.663751           62
# 77426   Shopper_1            2  37.784041 -122.407108           43
# 97946   Shopper_1            1  35.265121 -114.246687           20
# 32914   Shopper_1            0  37.784059 -122.406598          108
# ...           ...          ...        ...         ...          ...
# 418     Shopper_1            1  30.227255  -97.925648           20
# 37372   Shopper_1            0  37.784085 -122.407009          108
# 21770   Shopper_1            0  33.968828 -110.133960           20
# 28495   Shopper_1            2  35.561458 -115.206698           63
# 28513   Shopper_1            1  34.349118 -111.279163           39
# 93921   Shopper_1            2  37.784079 -122.407114           43
# 50871   Shopper_1            1  33.565384 -108.788102           20
# 61183   Shopper_1            0  31.971140 -103.575216           20
# 50835   Shopper_1            3  34.877596 -112.991172           62
# 21547   Shopper_1            3  37.784064 -122.407207          119
# 61182   Shopper_1            4  35.756717 -115.930223           19
# 74866   Shopper_1            1  37.757750 -122.383892          128
# 74855   Shopper_1            2  37.762391 -122.388008           43
# 55291   Shopper_1            2  37.783956 -122.407213           43
# 74843   Shopper_1            3  37.784077 -122.407058          119
# 74806   Shopper_1            0  37.784168 -122.406034          108
# 74805   Shopper_1            1  34.635384 -112.206523           39
# 41665   Shopper_1            1  35.539867 -115.187304           14
# 50625   Shopper_1            0  35.644070 -115.570418           64
# 50624   Shopper_1            3  37.784065 -122.407157          119
# 93848   Shopper_1            1  32.746176 -106.086128           20
# 11819   Shopper_1            2  37.784077 -122.407058           43
# 85044   Shopper_1            0  28.338040  -91.805298           20
# 85045   Shopper_1            3  35.539812 -115.187564           62
# 11637   Shopper_1            0  37.784120 -122.406620          108
# 60944   Shopper_1            0  37.784048 -122.407212          108
# 85061   Shopper_1            2  34.635388 -112.206498            0
# 85080   Shopper_1            1  32.386344 -104.920316           20
# 74419   Shopper_1            1  33.585855 -108.806241           20
# 61181   Shopper_1            1  37.784032 -122.407175          128
#
#                  Store_Name  Store_Index2  Store_Index3
# 35181              Solstice            93            27
# 70238        Bloomingdale's             2             2
# 70264   ProActiv Solutions             93            27
# 40491             Cotton On            85            45
# 4777      Bath & Body Works            43            11
# 4776         Bloomingdale's            93            27
# 101158       Bloomingdale's             2             2
# 49054                PacSun            43            11
# 22621        Bloomingdale's            43            11
# 22620        Bloomingdale's             2             2
# 22619      49ers Team Store            85            45
# 52049        Bloomingdale's            20             0
# 95887        Bloomingdale's            20            22
# 98815   ProActiv Solutions             85            45
# 78061        Bloomingdale's            20            20
# 106999       Bloomingdale's            85            45
# 78035   ProActiv Solutions             85            45
# 77973              Solstice            20             0
# 100499             Solstice            93            27
# 35762              Solstice            22            22
# 71239              Solstice            93            27
# 97924   ProActiv Solutions             85            45
# 102120  ProActiv Solutions             20             0
# 97101        Bloomingdale's            43            11
# 47032   ProActiv Solutions             20            20
# 25665           Sarku Japan           119            55
# 25664                   H&M            20            16
# 77426             Cotton On            85            45
# 97946        Bloomingdale's            20             0
# 32914   ProActiv Solutions              2             2
# ...                     ...           ...           ...
# 418          Bloomingdale's            31            16
# 37372   ProActiv Solutions              2             2
# 21770        Bloomingdale's            93            27
# 28495               H&M Man            22            22
# 28513     Club Monaco Women           119            55
# 93921             Cotton On             2             2
# 50871        Bloomingdale's             2             2
# 61183        Bloomingdale's            85            45
# 50835                   H&M           119            55
# 21547              Solstice           119            55
# 61182        Bespoke Events            20            20
# 74866             Swarovski            85            45
# 74855             Cotton On             2             2
# 55291             Cotton On            85            45
# 74843              Solstice            77            45
# 74806   ProActiv Solutions             85            45
# 74805     Club Monaco Women            20            20
# 41665                  BOSS            20            20
# 50625           Haagen Dazs            20            20
# 50624              Solstice            85            45
# 93848        Bloomingdale's            43            11
# 11819             Cotton On            20            16
# 85044        Bloomingdale's            93            27
# 85045                   H&M             2             2
# 11637   ProActiv Solutions              2             2
# 60944   ProActiv Solutions             85            45
# 85061      49ers Team Store             2             2
# 85080        Bloomingdale's            43            11
# 74419        Bloomingdale's             2             2
# 61181             Swarovski             2             2
#
# [100 rows x 8 columns]

# %%
inv_class_mapping = {v: k for k, v in store_mapping.items()}
pinginfo['Store_Name3'] = pinginfo['Store_Index3'].map(inv_class_mapping)

# %%
pinginfo.head(100)
# Out:
#        Shopper_ID  Floor_Index   latitude   longitude  Store_Index  \
# 35181   Shopper_1            3  37.762391 -122.388008          119
# 70238   Shopper_1            0  33.585825 -108.806374           20
# 70264   Shopper_1            0  37.784023 -122.406786          108
# 40491   Shopper_1            2  37.761052 -122.386801           43
# 4777    Shopper_1            3  35.664542 -115.588398           16
# 4776    Shopper_1            0  32.386375 -104.920369           20
# 101158  Shopper_1            1  34.005662 -110.166421           20
# 49054   Shopper_1            0  35.399517 -114.736228           99
# 22621   Shopper_1            1  32.721647 -106.064451           20
# 22620   Shopper_1            0  17.523494  -56.901809           20
# 22619   Shopper_1            2  34.349167 -111.279150            0
# 52049   Shopper_1            3  31.486702 -102.005952           20
# 95887   Shopper_1            1  33.061045 -107.106172           20
# 98815   Shopper_1            0  37.784038 -122.406711          108
# 78061   Shopper_1            1  31.971133 -103.575228           20
# 106999  Shopper_1            0  33.061063 -107.106165           20
# 78035   Shopper_1            0  37.784263 -122.405984          108
# 77973   Shopper_1            3  37.784085 -122.407135          119
# 100499  Shopper_1            3  37.784018 -122.407150          119
# 35762   Shopper_1            3  37.784052 -122.407079          119
# 71239   Shopper_1            3  37.784055 -122.407086          119
# 97924   Shopper_1            0  37.784075 -122.407065          108
# 102120  Shopper_1            0  37.784055 -122.407176          108
# 97101   Shopper_1            2  33.787407 -109.504903           20
# 47032   Shopper_1            0  37.784077 -122.407172          108
# 25665   Shopper_1            0  34.349141 -111.278963          116
# 25664   Shopper_1            3  35.085205 -113.663751           62
# 77426   Shopper_1            2  37.784041 -122.407108           43
# 97946   Shopper_1            1  35.265121 -114.246687           20
# 32914   Shopper_1            0  37.784059 -122.406598          108
# ...           ...          ...        ...         ...          ...
# 418     Shopper_1            1  30.227255  -97.925648           20
# 37372   Shopper_1            0  37.784085 -122.407009          108
# 21770   Shopper_1            0  33.968828 -110.133960           20
# 28495   Shopper_1            2  35.561458 -115.206698           63
# 28513   Shopper_1            1  34.349118 -111.279163           39
# 93921   Shopper_1            2  37.784079 -122.407114           43
# 50871   Shopper_1            1  33.565384 -108.788102           20
# 61183   Shopper_1            0  31.971140 -103.575216           20
# 50835   Shopper_1            3  34.877596 -112.991172           62
# 21547   Shopper_1            3  37.784064 -122.407207          119
# 61182   Shopper_1            4  35.756717 -115.930223           19
# 74866   Shopper_1            1  37.757750 -122.383892          128
# 74855   Shopper_1            2  37.762391 -122.388008           43
# 55291   Shopper_1            2  37.783956 -122.407213           43
# 74843   Shopper_1            3  37.784077 -122.407058          119
# 74806   Shopper_1            0  37.784168 -122.406034          108
# 74805   Shopper_1            1  34.635384 -112.206523           39
# 41665   Shopper_1            1  35.539867 -115.187304           14
# 50625   Shopper_1            0  35.644070 -115.570418           64
# 50624   Shopper_1            3  37.784065 -122.407157          119
# 93848   Shopper_1            1  32.746176 -106.086128           20
# 11819   Shopper_1            2  37.784077 -122.407058           43
# 85044   Shopper_1            0  28.338040  -91.805298           20
# 85045   Shopper_1            3  35.539812 -115.187564           62
# 11637   Shopper_1            0  37.784120 -122.406620          108
# 60944   Shopper_1            0  37.784048 -122.407212          108
# 85061   Shopper_1            2  34.635388 -112.206498            0
# 85080   Shopper_1            1  32.386344 -104.920316           20
# 74419   Shopper_1            1  33.585855 -108.806241           20
# 61181   Shopper_1            1  37.784032 -122.407175          128
#
#                  Store_Name  Store_Index2  Store_Index3  \
# 35181              Solstice            93            27
# 70238        Bloomingdale's             2             2
# 70264   ProActiv Solutions             93            27
# 40491             Cotton On            85            45
# 4777      Bath & Body Works            43            11
# 4776         Bloomingdale's            93            27
# 101158       Bloomingdale's             2             2
# 49054                PacSun            43            11
# 22621        Bloomingdale's            43            11
# 22620        Bloomingdale's             2             2
# 22619      49ers Team Store            85            45
# 52049        Bloomingdale's            20             0
# 95887        Bloomingdale's            20            22
# 98815   ProActiv Solutions             85            45
# 78061        Bloomingdale's            20            20
# 106999       Bloomingdale's            85            45
# 78035   ProActiv Solutions             85            45
# 77973              Solstice            20             0
# 100499             Solstice            93            27
# 35762              Solstice            22            22
# 71239              Solstice            93            27
# 97924   ProActiv Solutions             85            45
# 102120  ProActiv Solutions             20             0
# 97101        Bloomingdale's            43            11
# 47032   ProActiv Solutions             20            20
# 25665           Sarku Japan           119            55
# 25664                   H&M            20            16
# 77426             Cotton On            85            45
# 97946        Bloomingdale's            20             0
# 32914   ProActiv Solutions              2             2
# ...                     ...           ...           ...
# 418          Bloomingdale's            31            16
# 37372   ProActiv Solutions              2             2
# 21770        Bloomingdale's            93            27
# 28495               H&M Man            22            22
# 28513     Club Monaco Women           119            55
# 93921             Cotton On             2             2
# 50871        Bloomingdale's             2             2
# 61183        Bloomingdale's            85            45
# 50835                   H&M           119            55
# 21547              Solstice           119            55
# 61182        Bespoke Events            20            20
# 74866             Swarovski            85            45
# 74855             Cotton On             2             2
# 55291             Cotton On            85            45
# 74843              Solstice            77            45
# 74806   ProActiv Solutions             85            45
# 74805     Club Monaco Women            20            20
# 41665                  BOSS            20            20
# 50625           Haagen Dazs            20            20
# 50624              Solstice            85            45
# 93848        Bloomingdale's            43            11
# 11819             Cotton On            20            16
# 85044        Bloomingdale's            93            27
# 85045                   H&M             2             2
# 11637   ProActiv Solutions              2             2
# 60944   ProActiv Solutions             85            45
# 85061      49ers Team Store             2             2
# 85080        Bloomingdale's            43            11
# 74419        Bloomingdale's             2             2
# 61181             Swarovski             2             2
#
#                    Store_Name3
# 35181   Burke Williams Day Spa
# 70238                   Adidas
# 70264   Burke Williams Day Spa
# 40491                DAVIDsTEA
# 4777    Auntie Anne's Pretzels
# 4776    Burke Williams Day Spa
# 101158                  Adidas
# 49054   Auntie Anne's Pretzels
# 22621   Auntie Anne's Pretzels
# 22620                   Adidas
# 22619                DAVIDsTEA
# 52049         49ers Team Store
# 95887    Brighton Collectibles
# 98815                DAVIDsTEA
# 78061           Bloomingdale's
# 106999               DAVIDsTEA
# 78035                DAVIDsTEA
# 77973         49ers Team Store
# 100499  Burke Williams Day Spa
# 35762    Brighton Collectibles
# 71239   Burke Williams Day Spa
# 97924                DAVIDsTEA
# 102120        49ers Team Store
# 97101   Auntie Anne's Pretzels
# 47032           Bloomingdale's
# 25665                   Fossil
# 25664        Bath & Body Works
# 77426                DAVIDsTEA
# 97946         49ers Team Store
# 32914                   Adidas
# ...                        ...
# 418          Bath & Body Works
# 37372                   Adidas
# 21770   Burke Williams Day Spa
# 28495    Brighton Collectibles
# 28513                   Fossil
# 93921                   Adidas
# 50871                   Adidas
# 61183                DAVIDsTEA
# 50835                   Fossil
# 21547                   Fossil
# 61182           Bloomingdale's
# 74866                DAVIDsTEA
# 74855                   Adidas
# 55291                DAVIDsTEA
# 74843                DAVIDsTEA
# 74806                DAVIDsTEA
# 74805           Bloomingdale's
# 41665           Bloomingdale's
# 50625           Bloomingdale's
# 50624                DAVIDsTEA
# 93848   Auntie Anne's Pretzels
# 11819        Bath & Body Works
# 85044   Burke Williams Day Spa
# 85045                   Adidas
# 11637                   Adidas
# 60944                DAVIDsTEA
# 85061                   Adidas
# 85080   Auntie Anne's Pretzels
# 74419                   Adidas
# 61181                   Adidas
#
# [100 rows x 9 columns]

# %%
#pinginfo.groupby(['Shopper_ID', 'Store_Name3']).describe()

# %%
from scipy import stats
df_freq3 = pinginfo.groupby(by='Shopper_ID').Store_Name3.apply(stats.mode)

# %%
df_freq3
# Out:
# Shopper_ID
# Shopper_1         ([Adidas], [41])
# Shopper_10     ([DAVIDsTEA], [46])
# Shopper_100    ([DAVIDsTEA], [48])
# Shopper_101    ([DAVIDsTEA], [46])
# Shopper_102    ([DAVIDsTEA], [55])
# Shopper_103    ([DAVIDsTEA], [44])
# Shopper_104    ([DAVIDsTEA], [45])
# Shopper_105    ([DAVIDsTEA], [48])
# Shopper_106    ([DAVIDsTEA], [41])
# Shopper_107    ([DAVIDsTEA], [53])
# Shopper_108    ([DAVIDsTEA], [61])
# Shopper_109    ([DAVIDsTEA], [40])
# Shopper_11        ([Adidas], [39])
# Shopper_110    ([DAVIDsTEA], [53])
# Shopper_111    ([DAVIDsTEA], [63])
# Shopper_112    ([DAVIDsTEA], [42])
# Shopper_113    ([DAVIDsTEA], [53])
# Shopper_114    ([DAVIDsTEA], [49])
# Shopper_115    ([DAVIDsTEA], [51])
# Shopper_116    ([DAVIDsTEA], [44])
# Shopper_117    ([DAVIDsTEA], [41])
# Shopper_118    ([DAVIDsTEA], [42])
# Shopper_119    ([DAVIDsTEA], [47])
# Shopper_12     ([DAVIDsTEA], [45])
# Shopper_120    ([DAVIDsTEA], [54])
# Shopper_121    ([DAVIDsTEA], [40])
# Shopper_122    ([DAVIDsTEA], [46])
# Shopper_123    ([DAVIDsTEA], [50])
# Shopper_124       ([Adidas], [43])
# Shopper_125    ([DAVIDsTEA], [48])
#                       ...
# Shopper_72     ([DAVIDsTEA], [50])
# Shopper_73     ([DAVIDsTEA], [45])
# Shopper_74        ([Adidas], [48])
# Shopper_75     ([DAVIDsTEA], [52])
# Shopper_76     ([DAVIDsTEA], [58])
# Shopper_77     ([DAVIDsTEA], [52])
# Shopper_78     ([DAVIDsTEA], [42])
# Shopper_79     ([DAVIDsTEA], [43])
# Shopper_8      ([DAVIDsTEA], [55])
# Shopper_80     ([DAVIDsTEA], [54])
# Shopper_81     ([DAVIDsTEA], [49])
# Shopper_82     ([DAVIDsTEA], [51])
# Shopper_83     ([DAVIDsTEA], [57])
# Shopper_84     ([DAVIDsTEA], [57])
# Shopper_85     ([DAVIDsTEA], [44])
# Shopper_86     ([DAVIDsTEA], [50])
# Shopper_87     ([DAVIDsTEA], [56])
# Shopper_88     ([DAVIDsTEA], [54])
# Shopper_89     ([DAVIDsTEA], [57])
# Shopper_9      ([DAVIDsTEA], [51])
# Shopper_90     ([DAVIDsTEA], [51])
# Shopper_91     ([DAVIDsTEA], [60])
# Shopper_92     ([DAVIDsTEA], [50])
# Shopper_93     ([DAVIDsTEA], [46])
# Shopper_94     ([DAVIDsTEA], [43])
# Shopper_95     ([DAVIDsTEA], [47])
# Shopper_96     ([DAVIDsTEA], [43])
# Shopper_97     ([DAVIDsTEA], [42])
# Shopper_98     ([DAVIDsTEA], [48])
# Shopper_99     ([DAVIDsTEA], [44])
# Name: Store_Name3, Length: 567, dtype: object

# %%
#NOW FIND MOST STORE VISITED:

# %%
storemap.head()
# Out:
#                            Store_Name  Floor_Index   latitude   longitude  \
# 0                         Jamba Juice            0  37.784091 -122.406813
# 1              Coriander Gourmet Thai            0  37.784596 -122.406210
# 2                      NYS Collection            0  37.784396 -122.406587
# 3                            Hallmark            0  37.783771 -122.407377
# 4  Sorabol Korean BBQ & Asian Noodles            0  37.784601 -122.406328
#
#    Store_Index
# 0           69
# 1           41
# 2           91
# 3           65
# 4          120

# %%
pinginfonew=pinginfo.drop(['Store_Index2', 'Store_Index3','Store_Name3'], axis=1)
pinginfonew.head()
# Out:
#       Shopper_ID  Floor_Index   latitude   longitude  Store_Index  \
# 35181  Shopper_1            3  37.762391 -122.388008          119
# 70238  Shopper_1            0  33.585825 -108.806374           20
# 70264  Shopper_1            0  37.784023 -122.406786          108
# 40491  Shopper_1            2  37.761052 -122.386801           43
# 4777   Shopper_1            3  35.664542 -115.588398           16
#
#                 Store_Name
# 35181             Solstice
# 70238       Bloomingdale's
# 70264  ProActiv Solutions
# 40491            Cotton On
# 4777     Bath & Body Works

# %%
categorymapping.head()
# Out:
#           Store_Name Broad_Category    Fine_Category
# 0      Amazon Pop-Up         Retail            Misc.
# 1     Bespoke Events         Retail            Misc.
# 2  Bespoke Coworking         Retail  Specialty Store
# 3              Dyson         Retail            Misc.
# 4   Penhaligonï¿½Ûªs         Retail            Misc.

# %%
df_freq
# Out:
#                                  Store_Name            New_Store
# Shopper_ID
# Shopper_1          ([Bloomingdale's], [64])       Bloomingdale's
# Shopper_10                ([TAP 415], [80])              TAP 415
# Shopper_100   ([ProActiv Solutions ], [58])  ProActiv Solutions
# Shopper_101             ([Swarovski], [53])            Swarovski
# Shopper_102              ([TAP 415], [125])              TAP 415
# Shopper_103             ([Cotton On], [52])            Cotton On
# Shopper_104   ([ProActiv Solutions ], [71])  ProActiv Solutions
# Shopper_105   ([ProActiv Solutions ], [61])  ProActiv Solutions
# Shopper_106   ([ProActiv Solutions ], [63])  ProActiv Solutions
# Shopper_107   ([ProActiv Solutions ], [61])  ProActiv Solutions
# Shopper_108  ([ProActiv Solutions ], [105])  ProActiv Solutions
# Shopper_109        ([Bloomingdale's], [56])       Bloomingdale's
# Shopper_11    ([ProActiv Solutions ], [72])  ProActiv Solutions
# Shopper_110   ([ProActiv Solutions ], [51])  ProActiv Solutions
# Shopper_111             ([Swarovski], [56])            Swarovski
# Shopper_112   ([ProActiv Solutions ], [77])  ProActiv Solutions
# Shopper_113   ([ProActiv Solutions ], [97])  ProActiv Solutions
# Shopper_114               ([TAP 415], [90])              TAP 415
# Shopper_115             ([Cotton On], [55])            Cotton On
# Shopper_116              ([TAP 415], [167])              TAP 415
# Shopper_117  ([ProActiv Solutions ], [133])  ProActiv Solutions
# Shopper_118             ([Cotton On], [45])            Cotton On
# Shopper_119            ([Swarovski], [119])            Swarovski
# Shopper_12    ([ProActiv Solutions ], [32])  ProActiv Solutions
# Shopper_120             ([Swarovski], [59])            Swarovski
# Shopper_121   ([ProActiv Solutions ], [44])  ProActiv Solutions
# Shopper_122               ([TAP 415], [49])              TAP 415
# Shopper_123             ([Swarovski], [72])            Swarovski
# Shopper_124   ([ProActiv Solutions ], [75])  ProActiv Solutions
# Shopper_125             ([Cotton On], [41])            Cotton On
# ...                                     ...                  ...
# Shopper_72                ([TAP 415], [59])              TAP 415
# Shopper_73    ([ProActiv Solutions ], [51])  ProActiv Solutions
# Shopper_74    ([ProActiv Solutions ], [60])  ProActiv Solutions
# Shopper_75              ([Swarovski], [56])            Swarovski
# Shopper_76   ([ProActiv Solutions ], [116])  ProActiv Solutions
# Shopper_77                ([TAP 415], [41])              TAP 415
# Shopper_78              ([Cotton On], [54])            Cotton On
# Shopper_79              ([Cotton On], [55])            Cotton On
# Shopper_8               ([Swarovski], [57])            Swarovski
# Shopper_80    ([ProActiv Solutions ], [71])  ProActiv Solutions
# Shopper_81    ([ProActiv Solutions ], [46])  ProActiv Solutions
# Shopper_82                ([TAP 415], [56])              TAP 415
# Shopper_83    ([ProActiv Solutions ], [58])  ProActiv Solutions
# Shopper_84                ([TAP 415], [86])              TAP 415
# Shopper_85   ([ProActiv Solutions ], [107])  ProActiv Solutions
# Shopper_86    ([ProActiv Solutions ], [57])  ProActiv Solutions
# Shopper_87                ([TAP 415], [38])              TAP 415
# Shopper_88              ([Swarovski], [45])            Swarovski
# Shopper_89    ([ProActiv Solutions ], [76])  ProActiv Solutions
# Shopper_9     ([ProActiv Solutions ], [73])  ProActiv Solutions
# Shopper_90              ([Swarovski], [67])            Swarovski
# Shopper_91    ([ProActiv Solutions ], [77])  ProActiv Solutions
# Shopper_92    ([ProActiv Solutions ], [71])  ProActiv Solutions
# Shopper_93                ([TAP 415], [51])              TAP 415
# Shopper_94              ([Cotton On], [57])            Cotton On
# Shopper_95              ([Swarovski], [86])            Swarovski
# Shopper_96               ([Solstice], [38])             Solstice
# Shopper_97         ([Bloomingdale's], [42])       Bloomingdale's
# Shopper_98    ([ProActiv Solutions ], [66])  ProActiv Solutions
# Shopper_99    ([ProActiv Solutions ], [51])  ProActiv Solutions
#
# [567 rows x 2 columns]

# %%
'''Pick up category of stores from categorymapping and add it to the storemap and then train with storemap and predict on pinginfo'''
# Out:
# 'Pick up category of stores from categorymapping and add it to the storemap and then train with storemap and predict on pinginfo'

# %%
categorymapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 3 columns):
# Store_Name        154 non-null object
# Broad_Category    154 non-null object
# Fine_Category     154 non-null object
# dtypes: object(3)
# memory usage: 3.7+ KB

# %%
categorymapping.head()
# Out:
#           Store_Name Broad_Category    Fine_Category
# 0      Amazon Pop-Up         Retail            Misc.
# 1     Bespoke Events         Retail            Misc.
# 2  Bespoke Coworking         Retail  Specialty Store
# 3              Dyson         Retail            Misc.
# 4   Penhaligonï¿½Ûªs         Retail            Misc.

# %%
for stores, category in zip(categorymapping['Store_Name'], categorymapping['Fine_Category']):
    store_and_category_mapping = dict(zip(categorymapping['Store_Name'], categorymapping['Fine_Category']))

# %%
store_and_category_mapping
# Out:
# {u'49ers Team Store': u'Sports Stores',
#  u'Abercrombie & Fitch': u'Apparel And Accessories',
#  u'Adidas': u'Apparel And Accessories',
#  u'Ajisen Ramen': u'Qsr Restaurants',
#  u'Aldo': u'Shoe Stores',
#  u'Amazon Pop-Up': u'Misc.',
#  u'American Eagle Outfitters': u'Apparel And Accessories',
#  u'Amiri Salon': u'Furniture And Decor',
#  u'Amoura Cafe Fresh Mediterranean': u'Qsr Restaurants',
#  u'Andale Mexican Restaurant': u'Qsr Restaurants',
#  u'Aritzia': u'Apparel And Accessories',
#  u"Auntie Anne's Pretzels": u'Qsr Restaurants',
#  u'Aveda': u'Furniture And Decor',
#  u'BCBGMAXAZRIA': u'Apparel And Accessories',
#  u'BOSS': u'Apparel And Accessories',
#  u'Banana Republic': u'Apparel And Accessories',
#  u'Bath & Body Works': u'Furniture And Decor',
#  u"Beard Papa's Cream Puffs": u'Qsr Restaurants',
#  u'Bespoke Coworking': u'Specialty Store',
#  u'Bespoke Events': u'Misc.',
#  u"Bloomingdale's": u'Department Stores',
#  u'Bose': u'Electronics Stores',
#  u'Brighton Collectibles': u'Apparel And Accessories',
#  u'Bristol Farms': u'Casual Restaurants',
#  u'Brookstone': u'Department Stores',
#  u'Buckhorn Grill': u'Qsr Restaurants',
#  u'Burberry': u'Apparel And Accessories',
#  u'Burke Williams Day Spa': u'Misc.',
#  u'Cafe Bellini': u'Qsr Restaurants',
#  u'Caffe Central': u'Qsr Restaurants',
#  u'Cako Bakery': u'Qsr Restaurants',
#  u'Camper': u'Shoe Stores',
#  u'Century San Francisco Centre 9': u'Misc.',
#  u'Champs Sports': u'Sports Stores',
#  u"Charley's Grilled Subs": u'Qsr Restaurants',
#  u'Chipotle': u'Qsr Restaurants',
#  u"Claire's Boutique": u'Apparel And Accessories',
#  u'Clarks': u'Shoe Stores',
#  u'Club Monaco Men': u'Apparel And Accessories',
#  u'Club Monaco Women': u'Apparel And Accessories',
#  u'Coach': u'Apparel And Accessories',
#  u'Coriander Gourmet Thai': u'Qsr Restaurants',
#  u'Corner W': u'Shoe Stores',
#  u'Cotton On': u'Apparel And Accessories',
#  u'Currency Exchange International ': u'Misc.',
#  u'DAVIDsTEA': u'Qsr Restaurants',
#  u'Dyson': u'Misc.',
#  u'ECCO': u'Shoe Stores',
#  u'Eddie Bauer': u'Apparel And Accessories',
#  u'Express': u'Apparel And Accessories',
#  u'Eyebrow Plus': u'Furniture And Decor',
#  u'Finish Line': u'Apparel And Accessories',
#  u'Fire of Brazil': u'Qsr Restaurants',
#  u'Forever Flawless': u'Furniture And Decor',
#  u'Forever Flawless ': u'Furniture And Decor',
#  u'Fossil': u'Apparel And Accessories',
#  u"Francesca's Collection ": u'Apparel And Accessories',
#  u'GNC': u'Furniture And Decor',
#  u'GUESS ': u'Apparel And Accessories',
#  u'Ghirardelli Ice Cream and Chocolate Shop ': u'Qsr Restaurants',
#  u'Go! Toys and Games': u'Toy Stores',
#  u'Godiva Chocolatier': u'Qsr Restaurants',
#  u'H&M': u'Apparel And Accessories',
#  u'H&M Man': u'Apparel And Accessories',
#  u'Haagen Dazs': u'Qsr Restaurants',
#  u'Hallmark': u'Office Supply Stores',
#  u'Hollister Co.': u'Apparel And Accessories',
#  u'House of Hoops by Foot Locker': u'Sports Stores',
#  u'J.Crew': u'Apparel And Accessories',
#  u'Jamba Juice': u'Qsr Restaurants',
#  u'Janie And Jack': u'Apparel And Accessories',
#  u'Karen Millen': u'Apparel And Accessories',
#  u'Kate Spade New York': u'Apparel And Accessories',
#  u'Kay Jewelers': u'Misc.',
#  u'Kichi Grill': u'Qsr Restaurants',
#  u"Kiehl's": u'Furniture And Decor',
#  u"L'Occitane en Provence": u'Furniture And Decor',
#  u'LEGO': u'Toy Stores',
#  u'Lady Foot Locker': u'Sports Stores',
#  u'Lids': u'Apparel and Accessories',
#  u'Lobster Me': u'Qsr Restaurants',
#  u'Loving Hut Vegan Cuisine ': u'Qsr Restaurants',
#  u'Lucky Brand Jeans': u'Apparel And Accessories',
#  u'M.Y. China': u'Qsr Restaurants',
#  u'Madewell': u'Apparel And Accessories',
#  u'Marbles: The Brain Store': u'Toy Stores',
#  u'Max & Co.': u'Apparel And Accessories',
#  u'Michael Kors': u'Apparel And Accessories',
#  u'Michael Kors Men': u'Apparel And Accessories',
#  u'Microsoft': u'Electronics Stores',
#  u'Mrs. Fields': u'Qsr Restaurants',
#  u'NYS Collection': u'Apparel And Accessories',
#  u'New Era': u'Sports Stores',
#  u'Nordstrom': u'Department Stores',
#  u'Nordstrom E-Bar': u'Qsr Restaurants',
#  u'OAK+FORT': u'Apparel And Accessories',
#  u'Onassis': u'Furniture And Decor',
#  u'Optica': u'Furniture And Decor',
#  u'Origins': u'Furniture And Decor',
#  u'PacSun': u'Apparel And Accessories',
#  u'Panda Express': u'Qsr Restaurants',
#  u'Pandora': u'Misc.',
#  u'Papyrus': u'Office Supply Stores',
#  u'Pasta Moto': u'Qsr Restaurants',
#  u"Peet's Coffee & Tea": u'Qsr Restaurants',
#  u'Penhaligon\xef\xbf\xbd\xdb\xaas': u'Misc.',
#  u'Perfumania': u'Furniture And Decor',
#  u'Pressed Juicery': u'Qsr Restaurants',
#  u'ProActiv Solutions ': u'Misc.',
#  u'RED Valentino': u'Apparel And Accessories',
#  u'Razer': u'Specialty Store',
#  u'Rolex': u'Misc.',
#  u'SF Sports': u'Apparel And Accessories',
#  u'Samsonite': u'Apparel and Accessories',
#  u'San Francisco Luggage Co.': u'Apparel and Accessories',
#  u'San Francisco Soup Company': u'Qsr Restaurants',
#  u'Sarku Japan': u'Qsr Restaurants',
#  u'Shoe Palace ': u'Shoe Stores',
#  u'Shoe Wiz': u'Misc.',
#  u'Solstice': u'Apparel And Accessories',
#  u'Sorabol Korean BBQ & Asian Noodles': u'Qsr Restaurants',
#  u'Starbucks': u'Qsr Restaurants',
#  u'Steve Madden': u'Shoe Stores',
#  u'Studio Manhattan': u'Apparel and Accessories',
#  u'Sunglass Hut': u'Apparel And Accessories',
#  u'Sunglass Hut ': u'Apparel And Accessories',
#  u'Superdry ': u'Apparel And Accessories',
#  u'Sur La Table': u'Furniture And Decor',
#  u'Swarovski': u'Apparel and Accessories',
#  u'Swatch': u'Misc.',
#  u'T-Mobile': u'Cellular Phone Stores',
#  u'TAP 415': u'Qsr Restaurants',
#  u'Teavana': u'Qsr Restaurants',
#  u'The Art of Shaving': u'Furniture And Decor',
#  u'The Body Shop': u'Furniture And Decor',
#  u'The Walking Company': u'Shoe Stores',
#  u'Tiffany & Co.': u'Misc.',
#  u'Timberland': u'Apparel And Accessories',
#  u'Tory Burch ': u'Apparel And Accessories',
#  u'Tourneau': u'Misc.',
#  u'True Religion Jeans': u'Apparel And Accessories',
#  u'Tumi': u'Apparel and Accessories',
#  u'Vans': u'Shoe Stores',
#  u'Vera Bradley': u'Apparel And Accessories',
#  u"Victoria's Secret": u'Apparel And Accessories',
#  u'Warriors Team Store': u'Sports Stores',
#  u"Wetzel's Pretzels": u'Qsr Restaurants',
#  u'Yoppi Frozen Yogurt ': u'Qsr Restaurants',
#  u'Zara': u'Apparel And Accessories',
#  u'abercrombie kids': u'Apparel And Accessories',
#  u'bareMinerals': u'Furniture And Decor',
#  u'bebe': u'Apparel And Accessories',
#  u'iPlay n Talk': u'Electronics Stores',
#  u'lululemon athletica': u'Apparel and Accessories'}

# %%
storemap['Store_Category'] = storemap['Store_Name'].map(store_and_category_mapping).astype(object)
storemap.head()
# Out:
#                            Store_Name  Floor_Index   latitude   longitude  \
# 0                         Jamba Juice            0  37.784091 -122.406813
# 1              Coriander Gourmet Thai            0  37.784596 -122.406210
# 2                      NYS Collection            0  37.784396 -122.406587
# 3                            Hallmark            0  37.783771 -122.407377
# 4  Sorabol Korean BBQ & Asian Noodles            0  37.784601 -122.406328
#
#    Store_Index           Store_Category
# 0           69          Qsr Restaurants
# 1           41          Qsr Restaurants
# 2           91  Apparel And Accessories
# 3           65     Office Supply Stores
# 4          120          Qsr Restaurants

# %%
Store_Categories= sorted(storemap['Store_Category'].unique())
Store_Categories
# Out:
# [u'Apparel And Accessories',
#  u'Apparel and Accessories',
#  u'Casual Restaurants',
#  u'Cellular Phone Stores',
#  u'Department Stores',
#  u'Electronics Stores',
#  u'Furniture And Decor',
#  u'Misc.',
#  u'Office Supply Stores',
#  u'Qsr Restaurants',
#  u'Shoe Stores',
#  u'Specialty Store',
#  u'Sports Stores',
#  u'Toy Stores']

# %%
Store_Categories_mapping = dict(zip(Store_Categories, range(0, len(Store_Categories) + 1)))
Store_Categories_mapping
# Out:
# {u'Apparel And Accessories': 0,
#  u'Apparel and Accessories': 1,
#  u'Casual Restaurants': 2,
#  u'Cellular Phone Stores': 3,
#  u'Department Stores': 4,
#  u'Electronics Stores': 5,
#  u'Furniture And Decor': 6,
#  u'Misc.': 7,
#  u'Office Supply Stores': 8,
#  u'Qsr Restaurants': 9,
#  u'Shoe Stores': 10,
#  u'Specialty Store': 11,
#  u'Sports Stores': 12,
#  u'Toy Stores': 13}

# %%
storemap['Category_Index'] = storemap['Store_Category'].map(Store_Categories_mapping).astype(int)
storemap.head()
# Out:
#                            Store_Name  Floor_Index   latitude   longitude  \
# 0                         Jamba Juice            0  37.784091 -122.406813
# 1              Coriander Gourmet Thai            0  37.784596 -122.406210
# 2                      NYS Collection            0  37.784396 -122.406587
# 3                            Hallmark            0  37.783771 -122.407377
# 4  Sorabol Korean BBQ & Asian Noodles            0  37.784601 -122.406328
#
#    Store_Index           Store_Category  Category_Index
# 0           69          Qsr Restaurants               9
# 1           41          Qsr Restaurants               9
# 2           91  Apparel And Accessories               0
# 3           65     Office Supply Stores               8
# 4          120          Qsr Restaurants               9

# %%
X2 = storemap.drop(['Store_Name','Store_Index', 'Store_Category','Category_Index'],axis=1).as_matrix().astype(np.float)
X2
# Out:
# array([[   0.      ,   37.784091, -122.406813],
#        [   0.      ,   37.784596, -122.40621 ],
#        [   0.      ,   37.784396, -122.406587],
#        [   0.      ,   37.783771, -122.407377],
#        [   0.      ,   37.784601, -122.406328],
#        [   0.      ,   37.784534, -122.406025],
#        [   0.      ,   37.783944, -122.407537],
#        [   0.      ,   37.784447, -122.406224],
#        [   0.      ,   37.784161, -122.4069  ],
#        [   0.      ,   37.784808, -122.406501],
#        [   0.      ,   37.784569, -122.406141],
#        [   0.      ,   37.78467 , -122.406679],
#        [   0.      ,   37.784126, -122.407061],
#        [   0.      ,   37.784159, -122.40635 ],
#        [   0.      ,   37.783959, -122.40691 ],
#        [   0.      ,   37.784411, -122.406709],
#        [   0.      ,   37.784511, -122.405956],
#        [   0.      ,   37.784071, -122.406885],
#        [   0.      ,   37.784591, -122.406782],
#        [   0.      ,   37.783778, -122.407161],
#        [   0.      ,   37.784053, -122.407307],
#        [   0.      ,   37.783893, -122.407389],
#        [   0.      ,   37.784222, -122.406978],
#        [   0.      ,   37.783953, -122.407318],
#        [   0.      ,   37.784505, -122.406555],
#        [   0.      ,   37.783767, -122.40707 ],
#        [   0.      ,   37.784106, -122.407189],
#        [   0.      ,   37.784292, -122.40601 ],
#        [   0.      ,   37.784449, -122.406665],
#        [   0.      ,   37.784353, -122.406773],
#        [   0.      ,   37.784294, -122.406164],
#        [   0.      ,   37.78432 , -122.406195],
#        [   0.      ,   37.783944, -122.407175],
#        [   0.      ,   37.783831, -122.406941],
#        [   0.      ,   37.784312, -122.405822],
#        [   0.      ,   37.783887, -122.405783],
#        [   0.      ,   37.784208, -122.40743 ],
#        [   0.      ,   37.784505, -122.406399],
#        [   0.      ,   37.784625, -122.406417],
#        [   0.      ,   37.784123, -122.40695 ],
#        [   0.      ,   37.78413 , -122.407374],
#        [   0.      ,   37.784037, -122.406937],
#        [   0.      ,   37.784457, -122.406819],
#        [   0.      ,   37.784415, -122.405846],
#        [   0.      ,   37.784116, -122.407124],
#        [   0.      ,   37.784157, -122.405925],
#        [   0.      ,   37.784094, -122.407625],
#        [   0.      ,   37.783791, -122.406984],
#        [   1.      ,   37.78379 , -122.40747 ],
#        [   1.      ,   37.784615, -122.406332],
#        [   1.      ,   37.78402 , -122.405965],
#        [   1.      ,   37.784179, -122.406865],
#        [   1.      ,   37.784142, -122.40704 ],
#        [   1.      ,   37.784453, -122.406443],
#        [   1.      ,   37.784033, -122.406896],
#        [   1.      ,   37.784267, -122.406579],
#        [   1.      ,   37.784296, -122.406519],
#        [   1.      ,   37.784464, -122.406181],
#        [   1.      ,   37.784195, -122.40696 ],
#        [   1.      ,   37.784221, -122.406652],
#        [   1.      ,   37.784776, -122.406643],
#        [   1.      ,   37.784527, -122.406296],
#        [   1.      ,   37.78367 , -122.407313],
#        [   1.      ,   37.783731, -122.407122],
#        [   1.      ,   37.783976, -122.406906],
#        [   1.      ,   37.784613, -122.406467],
#        [   1.      ,   37.78398 , -122.407454],
#        [   1.      ,   37.784714, -122.406476],
#        [   1.      ,   37.78409 , -122.406835],
#        [   1.      ,   37.784503, -122.406813],
#        [   1.      ,   37.784112, -122.406949],
#        [   1.      ,   37.784884, -122.406486],
#        [   1.      ,   37.78461 , -122.406886],
#        [   1.      ,   37.784466, -122.406961],
#        [   1.      ,   37.78447 , -122.40676 ],
#        [   1.      ,   37.78373 , -122.407061],
#        [   1.      ,   37.783909, -122.407393],
#        [   1.      ,   37.78381 , -122.407336],
#        [   1.      ,   37.783864, -122.406836],
#        [   1.      ,   37.784188, -122.407159],
#        [   1.      ,   37.783827, -122.407024],
#        [   1.      ,   37.784047, -122.407035],
#        [   1.      ,   37.784397, -122.406148],
#        [   1.      ,   37.784185, -122.406379],
#        [   1.      ,   37.784396, -122.406726],
#        [   2.      ,   37.784579, -122.406476],
#        [   2.      ,   37.783744, -122.407323],
#        [   2.      ,   37.784515, -122.406218],
#        [   2.      ,   37.784024, -122.407272],
#        [   2.      ,   37.784139, -122.407183],
#        [   2.      ,   37.784341, -122.406785],
#        [   2.      ,   37.784559, -122.40627 ],
#        [   2.      ,   37.784136, -122.405805],
#        [   2.      ,   37.784705, -122.406568],
#        [   2.      ,   37.784142, -122.40742 ],
#        [   2.      ,   37.784267, -122.406528],
#        [   2.      ,   37.784046, -122.406884],
#        [   2.      ,   37.784252, -122.406942],
#        [   2.      ,   37.784387, -122.406732],
#        [   2.      ,   37.783739, -122.407271],
#        [   2.      ,   37.783745, -122.407149],
#        [   2.      ,   37.784385, -122.406276],
#        [   2.      ,   37.784195, -122.407081],
#        [   2.      ,   37.784433, -122.40608 ],
#        [   2.      ,   37.784031, -122.406181],
#        [   2.      ,   37.783852, -122.405805],
#        [   2.      ,   37.783931, -122.406086],
#        [   2.      ,   37.784484, -122.406502],
#        [   2.      ,   37.783724, -122.406893],
#        [   2.      ,   37.784555, -122.406814],
#        [   2.      ,   37.783832, -122.407021],
#        [   2.      ,   37.783954, -122.407507],
#        [   2.      ,   37.784185, -122.406432],
#        [   2.      ,   37.783864, -122.406924],
#        [   2.      ,   37.783946, -122.406796],
#        [   2.      ,   37.784316, -122.40656 ],
#        [   2.      ,   37.784172, -122.406733],
#        [   2.      ,   37.784271, -122.406619],
#        [   2.      ,   37.784286, -122.406001],
#        [   3.      ,   37.784042, -122.406901],
#        [   3.      ,   37.783629, -122.407154],
#        [   3.      ,   37.783741, -122.406902],
#        [   3.      ,   37.784628, -122.406187],
#        [   3.      ,   37.78435 , -122.406064],
#        [   3.      ,   37.784105, -122.406326],
#        [   3.      ,   37.784615, -122.406862],
#        [   3.      ,   37.784428, -122.406643],
#        [   3.      ,   37.784447, -122.406809],
#        [   3.      ,   37.783986, -122.406922],
#        [   3.      ,   37.783839, -122.406836],
#        [   3.      ,   37.783812, -122.406021],
#        [   3.      ,   37.784133, -122.407419],
#        [   3.      ,   37.783752, -122.407371],
#        [   3.      ,   37.78429 , -122.406561],
#        [   3.      ,   37.783737, -122.407253],
#        [   3.      ,   37.78424 , -122.406455],
#        [   3.      ,   37.784101, -122.406854],
#        [   3.      ,   37.783871, -122.407073],
#        [   3.      ,   37.784153, -122.405871],
#        [   3.      ,   37.783745, -122.405601],
#        [   3.      ,   37.784191, -122.407111],
#        [   3.      ,   37.784267, -122.405933],
#        [   3.      ,   37.784386, -122.406589],
#        [   3.      ,   37.78454 , -122.406132],
#        [   3.      ,   37.783912, -122.407474],
#        [   3.      ,   37.784663, -122.406313],
#        [   3.      ,   37.784135, -122.406406],
#        [   3.      ,   37.783957, -122.406249],
#        [   3.      ,   37.783814, -122.407399],
#        [   3.      ,   37.784197, -122.40698 ],
#        [   3.      ,   37.784701, -122.406758],
#        [   3.      ,   37.78436 , -122.406786],
#        [   4.      ,   37.78442 , -122.406832],
#        [   4.      ,   37.784702, -122.406248],
#        [   4.      ,   37.784206, -122.406528],
#        [   4.      ,   37.784178, -122.405776],
#        [   4.      ,   37.783859, -122.40635 ],
#        [   4.      ,   37.784539, -122.406081],
#        [   4.      ,   37.78382 , -122.407311],
#        [   4.      ,   37.783802, -122.405736],
#        [   5.      ,   37.784076, -122.407307],
#        [   5.      ,   37.78389 , -122.405736],
#        [   5.      ,   37.784204, -122.406574],
#        [   6.      ,   37.78409 , -122.407309],
#        [   7.      ,   37.784073, -122.407289],
#        [   8.      ,   37.784087, -122.407307]])

# %%
y2 = storemap['Store_Category'].as_matrix().astype(object)
y2
# Out:
# array([u'Qsr Restaurants', u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Office Supply Stores', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Misc.',
#        u'Shoe Stores', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Casual Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Furniture And Decor', u'Sports Stores', u'Toy Stores',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Shoe Stores', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Toy Stores', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Department Stores', u'Sports Stores', u'Qsr Restaurants',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Misc.',
#        u'Qsr Restaurants', u'Furniture And Decor', u'Qsr Restaurants',
#        u'Sports Stores', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Qsr Restaurants', u'Specialty Store', u'Apparel And Accessories',
#        u'Department Stores', u'Misc.', u'Furniture And Decor', u'Misc.',
#        u'Apparel And Accessories', u'Furniture And Decor',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel and Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel and Accessories',
#        u'Apparel And Accessories', u'Misc.', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Furniture And Decor', u'Misc.',
#        u'Apparel And Accessories', u'Apparel And Accessories', u'Misc.',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Furniture And Decor', u'Apparel And Accessories', u'Misc.',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Furniture And Decor', u'Misc.',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel and Accessories', u'Apparel And Accessories',
#        u'Furniture And Decor', u'Furniture And Decor',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Furniture And Decor',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Shoe Stores', u'Sports Stores', u'Apparel And Accessories',
#        u'Misc.', u'Furniture And Decor', u'Apparel And Accessories',
#        u'Cellular Phone Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Sports Stores', u'Apparel and Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories', u'Misc.',
#        u'Apparel And Accessories', u'Electronics Stores',
#        u'Apparel and Accessories', u'Apparel And Accessories',
#        u'Furniture And Decor', u'Shoe Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Shoe Stores',
#        u'Apparel And Accessories', u'Office Supply Stores',
#        u'Apparel and Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Apparel And Accessories', u'Shoe Stores',
#        u'Sports Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Furniture And Decor', u'Misc.',
#        u'Furniture And Decor', u'Shoe Stores', u'Apparel and Accessories',
#        u'Electronics Stores', u'Toy Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Shoe Stores', u'Furniture And Decor',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Furniture And Decor',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Shoe Stores',
#        u'Furniture And Decor', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Furniture And Decor', u'Qsr Restaurants',
#        u'Specialty Store', u'Misc.', u'Electronics Stores',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Misc.', u'Misc.', u'Department Stores', u'Department Stores',
#        u'Department Stores'], dtype=object)

# %%
def stratified_cv(X, y, clf_class, shuffle=True, n_folds=2, **kwargs):
    stratified_k_fold = cross_validation.StratifiedKFold(y, n_folds=n_folds, shuffle=shuffle)
    y_pred = y.copy()
    for ii, jj in stratified_k_fold:
        X_train, X_test = X[ii], X[jj]
        y_train = y[ii]
        clf = clf_class(**kwargs)
        clf.fit(X_train,y_train)
        y_pred[jj] = clf.predict(X_test)
    return y_pred

# %%
print('Passive Aggressive Classifier: {:.2f}'.format(metrics.accuracy_score(y2, stratified_cv(X2, y2, linear_model.PassiveAggressiveClassifier))))
print('Gradient Boosting Classifier:  {:.2f}'.format(metrics.accuracy_score(y2, stratified_cv(X2, y2, ensemble.GradientBoostingClassifier))))
print('Support vector machine(SVM):   {:.2f}'.format(metrics.accuracy_score(y2, stratified_cv(X2, y2, svm.SVC))))
print('Random Forest Classifier:      {:.2f}'.format(metrics.accuracy_score(y2, stratified_cv(X2, y2, ensemble.RandomForestClassifier))))
print('K Nearest Neighbor Classifier: {:.2f}'.format(metrics.accuracy_score(y2, stratified_cv(X2, y2, neighbors.KNeighborsClassifier))))
print('Logistic Regression:           {:.2f}'.format(metrics.accuracy_score(y2, stratified_cv(X2, y2, linear_model.LogisticRegression))))
# Out:
# Passive Aggressive Classifier: 0.16
# Gradient Boosting Classifier:  0.32
# Support vector machine(SVM):   0.46
# Random Forest Classifier:      0.40
# K Nearest Neighbor Classifier: 0.43
# Logistic Regression:           0.48

# %%
import numpy as np
from sklearn.model_selection import train_test_split

from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics

# %%
#SVM TRAINING AND FITTING:
from sklearn.svm import SVC

clf = svm.SVC(kernel='rbf', gamma=2)
clf.fit(X2, y2)


# Training data features, skip the first column 'Survived'
train_features = X2

# 'Survived' column values
train_target = y2

# Fit the model to our training data
clf = clf.fit(train_features, train_target)
score = clf.score(train_features, train_target)
"Mean accuracy of SVM: {0}".format(score)
# Out:
# 'Mean accuracy of SVM: 0.5'

# %%
X_test2 = pinginfonew.drop(['Shopper_ID', 'Store_Index','Store_Name'], axis=1).as_matrix().astype(np.float)
X_test2
# Out:
# array([[   3.        ,   37.76239083, -122.3880078 ],
#        [   0.        ,   33.58582518, -108.806374  ],
#        [   0.        ,   37.78402307, -122.4067857 ],
#        ...,
#        [   1.        ,   37.78531785, -122.4096861 ],
#        [   4.        ,   34.23642783, -110.9600836 ],
#        [   1.        ,   36.25792852, -117.496074  ]])

# %%
pred_y2 = clf.predict(X_test2)

# %%
pinginfonew.head()
# Out:
#       Shopper_ID  Floor_Index   latitude   longitude  Store_Index  \
# 35181  Shopper_1            3  37.762391 -122.388008          119
# 70238  Shopper_1            0  33.585825 -108.806374           20
# 70264  Shopper_1            0  37.784023 -122.406786          108
# 40491  Shopper_1            2  37.761052 -122.386801           43
# 4777   Shopper_1            3  35.664542 -115.588398           16
#
#                 Store_Name
# 35181             Solstice
# 70238       Bloomingdale's
# 70264  ProActiv Solutions
# 40491            Cotton On
# 4777     Bath & Body Works

# %%
pinginfonew['Store_Category_visited'] = pred_y2

# %%
pinginfonew.head()
# Out:
#       Shopper_ID  Floor_Index   latitude   longitude  Store_Index  \
# 35181  Shopper_1            3  37.762391 -122.388008          119
# 70238  Shopper_1            0  33.585825 -108.806374           20
# 70264  Shopper_1            0  37.784023 -122.406786          108
# 40491  Shopper_1            2  37.761052 -122.386801           43
# 4777   Shopper_1            3  35.664542 -115.588398           16
#
#                 Store_Name   Store_Category_visited
# 35181             Solstice  Apparel And Accessories
# 70238       Bloomingdale's        Department Stores
# 70264  ProActiv Solutions           Qsr Restaurants
# 40491            Cotton On  Apparel And Accessories
# 4777     Bath & Body Works        Department Stores

# %%
from scipy import stats
df_freq_category = pinginfonew.groupby(by='Shopper_ID').Store_Category_visited.apply(stats.mode)

# %%
df_freq_category
# Out:
# Shopper_ID
# Shopper_1            ([Department Stores], [112])
# Shopper_10           ([Department Stores], [130])
# Shopper_100           ([Department Stores], [96])
# Shopper_101    ([Apparel And Accessories], [129])
# Shopper_102          ([Department Stores], [141])
# Shopper_103    ([Apparel And Accessories], [123])
# Shopper_104             ([Qsr Restaurants], [71])
# Shopper_105    ([Apparel And Accessories], [103])
# Shopper_106    ([Apparel And Accessories], [125])
# Shopper_107     ([Apparel And Accessories], [85])
# Shopper_108            ([Qsr Restaurants], [105])
# Shopper_109          ([Department Stores], [100])
# Shopper_11      ([Apparel And Accessories], [76])
# Shopper_110           ([Department Stores], [77])
# Shopper_111    ([Apparel And Accessories], [120])
# Shopper_112             ([Qsr Restaurants], [77])
# Shopper_113             ([Qsr Restaurants], [96])
# Shopper_114          ([Department Stores], [105])
# Shopper_115    ([Apparel And Accessories], [117])
# Shopper_116          ([Department Stores], [173])
# Shopper_117            ([Qsr Restaurants], [133])
# Shopper_118     ([Apparel And Accessories], [92])
# Shopper_119    ([Apparel And Accessories], [138])
# Shopper_12           ([Department Stores], [132])
# Shopper_120    ([Apparel And Accessories], [112])
# Shopper_121           ([Department Stores], [73])
# Shopper_122          ([Department Stores], [104])
# Shopper_123    ([Apparel And Accessories], [110])
# Shopper_124    ([Apparel And Accessories], [115])
# Shopper_125     ([Apparel And Accessories], [95])
#                               ...
# Shopper_72            ([Department Stores], [87])
# Shopper_73            ([Department Stores], [87])
# Shopper_74     ([Apparel And Accessories], [111])
# Shopper_75     ([Apparel And Accessories], [119])
# Shopper_76             ([Qsr Restaurants], [116])
# Shopper_77            ([Department Stores], [96])
# Shopper_78     ([Apparel And Accessories], [133])
# Shopper_79     ([Apparel And Accessories], [132])
# Shopper_8      ([Apparel And Accessories], [110])
# Shopper_80            ([Department Stores], [94])
# Shopper_81      ([Apparel And Accessories], [81])
# Shopper_82           ([Department Stores], [117])
# Shopper_83            ([Department Stores], [77])
# Shopper_84           ([Department Stores], [103])
# Shopper_85             ([Qsr Restaurants], [107])
# Shopper_86           ([Department Stores], [101])
# Shopper_87            ([Department Stores], [86])
# Shopper_88            ([Department Stores], [79])
# Shopper_89      ([Apparel And Accessories], [93])
# Shopper_9               ([Qsr Restaurants], [73])
# Shopper_90     ([Apparel And Accessories], [111])
# Shopper_91              ([Qsr Restaurants], [77])
# Shopper_92     ([Apparel And Accessories], [104])
# Shopper_93     ([Apparel And Accessories], [103])
# Shopper_94     ([Apparel And Accessories], [136])
# Shopper_95     ([Apparel And Accessories], [144])
# Shopper_96     ([Apparel And Accessories], [106])
# Shopper_97            ([Department Stores], [97])
# Shopper_98     ([Apparel And Accessories], [114])
# Shopper_99            ([Department Stores], [75])
# Name: Store_Category_visited, Length: 567, dtype: object

# %%
df_freq_category= df_freq_category.to_frame()
df_freq_category.iloc[1,:]
# Out:
# Store_Category_visited    ([Department Stores], [130])
# Name: Shopper_10, dtype: object

# %%
mostvisitedcategorylist= []
for category in df_freq_category['Store_Category_visited']:
    mostvisitedcategorylist.append(category[0][0])
    
mostvisitedcategory_array= np.array(mostvisitedcategorylist)
mostvisitedcategory_array
# Out:
# array([u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Qsr Restaurants', u'Department Stores',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Department Stores', u'Department Stores',
#        u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Department Stores', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Qsr Restaurants', u'Department Stores',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Qsr Restaurants', u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Qsr Restaurants', u'Department Stores',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Department Stores', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Qsr Restaurants', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Department Stores', u'Department Stores', u'Qsr Restaurants',
#        u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Qsr Restaurants', u'Department Stores',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Department Stores', u'Department Stores', u'Qsr Restaurants',
#        u'Department Stores', u'Department Stores', u'Department Stores',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Qsr Restaurants',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Apparel And Accessories',
#        u'Apparel And Accessories', u'Department Stores',
#        u'Apparel And Accessories', u'Department Stores'], dtype='<U23')

# %%
mostvisitedcategory_array.astype(object)
df_freq_category['New_Store_Category_visited']= mostvisitedcategory_array
df_freq_category.head()
# Out:
#                          Store_Category_visited New_Store_Category_visited
# Shopper_ID
# Shopper_1          ([Department Stores], [112])          Department Stores
# Shopper_10         ([Department Stores], [130])          Department Stores
# Shopper_100         ([Department Stores], [96])          Department Stores
# Shopper_101  ([Apparel And Accessories], [129])    Apparel And Accessories
# Shopper_102        ([Department Stores], [141])          Department Stores

# %%
df_freq_category.to_csv(r"C:\Users\welcome\Desktop\exl__svm2ndpart.csv")

# %%
frames = [df_freq, df_freq_category]
result = pd.concat(frames, axis=1)

# %%
result.to_csv(r"C:\Users\welcome\Desktop\exl__final.csv")
