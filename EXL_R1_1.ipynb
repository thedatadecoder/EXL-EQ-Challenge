# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')

# %%
File = pd.ExcelFile(r"C:\Users\welcome\Desktop\EXL CASES\ROUND 2\Data.xlsx")

# %%
File.sheet_names
# Out:
# [u'Demographics',
#  u'Store Mapping',
#  u'Category Mapping',
#  u'Ping_Information',
#  u'Variable Descriptions']

# %%
demographics= pd.read_excel(File, 'Demographics')
demographics.drop(['Unnamed: 0'], axis=1, inplace=True)
demographics
# Out:
#       Shopper_Id                                    ID  Age Gender  \
# 0      Shopper_1  831b9564-99d7-3b57-a9c0-3ac1f31560d5   23      F
# 1      Shopper_2  1bd5093b-5a76-3ccc-b0d2-37695a858a95   42      F
# 2      Shopper_3  d08139f8-c50d-3472-adf8-6dcc4724164c   51      F
# 3      Shopper_4  29b285af-f631-3100-9a4e-5de09df7f974   35      F
# 4      Shopper_5  63fc3248-9900-3074-b887-c6ed6d73d0e3   42      M
# 5      Shopper_6  3fe4135c-06c1-395c-923d-f10f3552dd75   50      M
# 6      Shopper_7  725954b6-5227-3d88-b6bf-8a6b822dd8d4   40      M
# 7      Shopper_8  c0b4b558-84e1-3400-8f6f-18db12478292   58      M
# 8      Shopper_9  eca4c7c4-7b92-3648-ba55-f84020ced575   36      F
# 9     Shopper_10  39a86f65-f08d-330b-8d37-57d082631adf   56      F
# 10    Shopper_11  178732a0-709f-37de-8188-becd7d4f859f   23      F
# 11    Shopper_12  b78feb44-2b0b-3131-9935-f0802c08db3f   61      M
# 12    Shopper_13  9cc20ae7-6b44-3c97-9f51-76789bbcf275   76      M
# ...

# %%
storemap = pd.read_excel(File, 'Store Mapping')
storemap.drop(['Unnamed: 0'], axis=1, inplace=True)
storemap
# Out:
#                                     Store_Name       Floor_name  Floor_Index  \
# 0                                  Jamba Juice  Concourse Level            0
# 1                       Coriander Gourmet Thai  Concourse Level            0
# 2                               NYS Collection  Concourse Level            0
# 3                                     Hallmark  Concourse Level            0
# 4           Sorabol Korean BBQ & Asian Noodles  Concourse Level            0
# 5                                   Pasta Moto  Concourse Level            0
# 6                          Abercrombie & Fitch  Concourse Level            0
# 7                               Fire of Brazil  Concourse Level            0
# 8                          ProActiv Solutions   Concourse Level            0
# 9                                     Corner W  Concourse Level            0
# 10                              Buckhorn Grill  Concourse Level            0
# ...

# %%
categorymap = pd.read_excel(File, 'Category Mapping')
pinginfo = pd.read_excel(File, 'Ping_Information')
categorymap.drop(['Unnamed: 0'],axis=1, inplace= True)
pinginfo.drop(['Unnamed: 0'],axis=1, inplace= True)

# %%
categorymap
# Out:
#                                     Store_Name Broad_Category  \
# 0                                Amazon Pop-Up         Retail
# 1                               Bespoke Events         Retail
# 2                            Bespoke Coworking         Retail
# 3                                        Dyson         Retail
# 4                             Penhaligonï¿½Ûªs         Retail
# 5                                    SF Sports         Retail
# 6                            Claire's Boutique         Retail
# 7                           Go! Toys and Games         Retail
# 8                                    Nordstrom         Retail
# 9                               Bloomingdale's         Retail
# 10                           Victoria's Secret         Retail
# 11                                      Adidas         Retail
# 12                                 Finish Line         Retail
# 13                                        Zara         Retail
# ...

# %%
pinginfo
# Out:
#          Shopper_ID      floor        lat         lng             x  \
# 0       Shopper_556    Floor 4  37.661463 -122.298673 -2.934558e+03
# 1       Shopper_556    Floor 1  37.784062 -122.406943  1.172625e+02
# 2       Shopper_556    Floor 4  37.784361 -122.406710  1.561251e+02
# 3       Shopper_360  Concourse  37.784341 -122.406891  1.344997e+02
# 4       Shopper_360    Floor 2  37.784017 -122.407307  9.498169e+01
# 5       Shopper_420    Floor 4  37.661624 -122.298459 -2.908687e+03
# 6       Shopper_420    Floor 1  37.783856 -122.407092  9.186057e+01
# 7       Shopper_245    Floor 2  37.783970 -122.407194  9.838965e+01
# 8       Shopper_334    Floor 2  37.783828 -122.406986  1.003072e+02
# 9       Shopper_205    Floor 1  37.784219 -122.406896  1.324179e+02
# 10      Shopper_205  Concourse  37.784638 -122.406411  1.876741e+02
# 11      Shopper_530    Floor 1  35.085149 -113.663734  3.376118e+05
# 12      Shopper_530  Concourse  36.541271 -118.435462  1.520991e+05
# ...

# %%
store_count = pd.read_csv(r"C:\Users\welcome\Desktop\EXL OUTPUTS\visiting_info_final - Copy.csv")
category_count = pd.read_csv(r"C:\Users\welcome\Desktop\EXL OUTPUTS\visiting_info2_final - Copy.csv")

# %%
'''for i in columns:
       mapping = dict(hero[['hero_id', i]].values)
       train[i] = train.hero_id.map(mapping)'''
# Out:
# "for i in columns:\n       mapping = dict(hero[['hero_id', i]].values)\n       train[i] = train.hero_id.map(mapping)"

# %%
category_count
# Out:
#        Shopper_ID   Store_Category_visited  count  Unnamed: 3  Unnamed: 4  \
# 0       Shopper_1  Apparel And Accessories     77         NaN         NaN
# 1       Shopper_1        Department Stores     45         NaN         NaN
# 2       Shopper_1      Furniture And Decor     30         NaN         NaN
# 3       Shopper_1                    Misc.      2         NaN         NaN
# 4       Shopper_1          Qsr Restaurants     35         NaN         NaN
# 5      Shopper_10  Apparel And Accessories     46         NaN         NaN
# 6      Shopper_10        Department Stores      1         NaN         NaN
# 7      Shopper_10      Furniture And Decor     30         NaN         NaN
# 8      Shopper_10                    Misc.      4         NaN         NaN
# 9      Shopper_10          Qsr Restaurants    102         NaN         NaN
# 10     Shopper_10              Shoe Stores      1         NaN         NaN
# 11     Shopper_10            Sports Stores      2         NaN         NaN
# ...

# %%
cols = [i for i in range(3,25)]
category_count.drop(category_count.columns[cols],axis=1, inplace=True)

# %%
category_count
# Out:
#        Shopper_ID   Store_Category_visited  count
# 0       Shopper_1  Apparel And Accessories     77
# 1       Shopper_1        Department Stores     45
# 2       Shopper_1      Furniture And Decor     30
# 3       Shopper_1                    Misc.      2
# 4       Shopper_1          Qsr Restaurants     35
# 5      Shopper_10  Apparel And Accessories     46
# 6      Shopper_10        Department Stores      1
# 7      Shopper_10      Furniture And Decor     30
# 8      Shopper_10                    Misc.      4
# 9      Shopper_10          Qsr Restaurants    102
# 10     Shopper_10              Shoe Stores      1
# 11     Shopper_10            Sports Stores      2
# 12     Shopper_10               Toy Stores      1
# 13    Shopper_100  Apparel And Accessories     62
# 14    Shopper_100        Department Stores     24
# 15    Shopper_100      Furniture And Decor     60
# 16    Shopper_100                    Misc.      5
# 17    Shopper_100          Qsr Restaurants     31
# ...

# %%
store_count
# Out:
#       Shopper_ID              Store_Name  count
# 0      Shopper_1        49ers Team Store      6
# 1      Shopper_1                    BOSS      1
# 2      Shopper_1          Bespoke Events      1
# 3      Shopper_1          Bloomingdale's     56
# 4      Shopper_1           Bristol Farms      8
# 5      Shopper_1       Club Monaco Women      2
# 6      Shopper_1               Cotton On     14
# 7      Shopper_1                     H&M     10
# 8      Shopper_1                 H&M Man      6
# 9      Shopper_1          Janie And Jack      3
# 10     Shopper_1     Kate Spade New York      2
# 11     Shopper_1              M.Y. China      1
# 12     Shopper_1     ProActiv Solutions      30
# 13     Shopper_1             Sarku Japan      1
# 14     Shopper_1            Steve Madden     18
# 15     Shopper_1               Swarovski     15
# 16     Shopper_1                 TAP 415      8
# 17     Shopper_1     The Walking Company      3
# 18     Shopper_1           Tiffany & Co.      2
# ...

# %%
categories = sorted(categorymap.Fine_Category.unique())
categories
# Out:
# [u'Apparel And Accessories',
#  u'Apparel and Accessories',
#  u'Casual Restaurants',
#  u'Cellular Phone Stores',
#  u'Department Stores',
#  u'Electronics Stores',
#  u'Furniture And Decor',
#  u'Misc.',
#  u'Office Supply Stores',
#  u'Qsr Restaurants',
#  u'Shoe Stores',
#  u'Specialty Store',
#  u'Sports Stores',
#  u'Toy Stores']

# %%
mapping = dict(categorymap[['Store_Name','Fine_Category' ]].values)
mapping
# Out:
# {u'49ers Team Store': u'Sports Stores',
#  u'Abercrombie & Fitch': u'Apparel And Accessories',
#  u'Adidas': u'Apparel And Accessories',
#  u'Ajisen Ramen': u'Qsr Restaurants',
#  u'Aldo': u'Shoe Stores',
#  u'Amazon Pop-Up': u'Misc.',
#  u'American Eagle Outfitters': u'Apparel And Accessories',
#  u'Amiri Salon': u'Furniture And Decor',
#  u'Amoura Cafe Fresh Mediterranean': u'Qsr Restaurants',
#  u'Andale Mexican Restaurant': u'Qsr Restaurants',
#  u'Aritzia': u'Apparel And Accessories',
#  u"Auntie Anne's Pretzels": u'Qsr Restaurants',
#  u'Aveda': u'Furniture And Decor',
#  u'BCBGMAXAZRIA': u'Apparel And Accessories',
#  u'BOSS': u'Apparel And Accessories',
#  u'Banana Republic': u'Apparel And Accessories',
#  u'Bath & Body Works': u'Furniture And Decor',
#  u"Beard Papa's Cream Puffs": u'Qsr Restaurants',
#  u'Bespoke Coworking': u'Specialty Store',
#  u'Bespoke Events': u'Misc.',
#  u"Bloomingdale's": u'Department Stores',
#  u'Bose': u'Electronics Stores',
# ...

# %%
store_count['Store_Category'] = store_count.Store_Name.map(mapping)
store_count
# Out:
#       Shopper_ID              Store_Name  count           Store_Category
# 0      Shopper_1        49ers Team Store      6            Sports Stores
# 1      Shopper_1                    BOSS      1  Apparel And Accessories
# 2      Shopper_1          Bespoke Events      1                    Misc.
# 3      Shopper_1          Bloomingdale's     56        Department Stores
# 4      Shopper_1           Bristol Farms      8       Casual Restaurants
# 5      Shopper_1       Club Monaco Women      2  Apparel And Accessories
# 6      Shopper_1               Cotton On     14  Apparel And Accessories
# 7      Shopper_1                     H&M     10  Apparel And Accessories
# 8      Shopper_1                 H&M Man      6  Apparel And Accessories
# 9      Shopper_1          Janie And Jack      3  Apparel And Accessories
# 10     Shopper_1     Kate Spade New York      2  Apparel And Accessories
# 11     Shopper_1              M.Y. China      1          Qsr Restaurants
# ...

# %%
storemap
# Out:
#                                     Store_Name       Floor_name  Floor_Index  \
# 0                                  Jamba Juice  Concourse Level            0
# 1                       Coriander Gourmet Thai  Concourse Level            0
# 2                               NYS Collection  Concourse Level            0
# 3                                     Hallmark  Concourse Level            0
# 4           Sorabol Korean BBQ & Asian Noodles  Concourse Level            0
# 5                                   Pasta Moto  Concourse Level            0
# 6                          Abercrombie & Fitch  Concourse Level            0
# 7                               Fire of Brazil  Concourse Level            0
# 8                          ProActiv Solutions   Concourse Level            0
# 9                                     Corner W  Concourse Level            0
# 10                              Buckhorn Grill  Concourse Level            0
# ...

# %%
columns= ['Floor_name', 'Floor_Index']
for i in columns:
    newmapping = dict(storemap[['Store_Name',i]].values)
    store_count[i] = store_count.Store_Name.map(newmapping)

# %%
store_count
# Out:
#       Shopper_ID              Store_Name  count           Store_Category  \
# 0      Shopper_1        49ers Team Store      6            Sports Stores
# 1      Shopper_1                    BOSS      1  Apparel And Accessories
# 2      Shopper_1          Bespoke Events      1                    Misc.
# 3      Shopper_1          Bloomingdale's     56        Department Stores
# 4      Shopper_1           Bristol Farms      8       Casual Restaurants
# 5      Shopper_1       Club Monaco Women      2  Apparel And Accessories
# 6      Shopper_1               Cotton On     14  Apparel And Accessories
# 7      Shopper_1                     H&M     10  Apparel And Accessories
# 8      Shopper_1                 H&M Man      6  Apparel And Accessories
# 9      Shopper_1          Janie And Jack      3  Apparel And Accessories
# 10     Shopper_1     Kate Spade New York      2  Apparel And Accessories
# 11     Shopper_1              M.Y. China      1          Qsr Restaurants
# ...

# %%
store_count.to_csv(r"C:\Users\welcome\Desktop\EXL OUTPUTS\new_store_counts.csv")

# %%
counts = pd.read_csv(r"C:\Users\welcome\Desktop\EXL OUTPUTS\store_counts.csv")

# %%
counts
# Out:
#                    Store_Name  count
# 0         ProActiv Solutions   27629
# 1                   Swarovski  18719
# 2                   Cotton On  15505
# 3                     TAP 415  10520
# 4                Steve Madden   9611
# 5              Bloomingdale's   8855
# 6               Bristol Farms   3698
# 7                     H&M Man   1467
# 8            49ers Team Store   1464
# 9              Bespoke Events   1252
# 10                 M.Y. China    991
# 11          Club Monaco Women    977
# 12     L'Occitane en Provence    792
# 13                     Camper    688
# 14             Janie And Jack    669
# 15                Sarku Japan    621
# 16             NYS Collection    504
# 17        Kate Spade New York    503
# 18      Brighton Collectibles    480
# 19                        H&M    479
# 20   Marbles: The Brain Store    479
# 21                       BOSS    322
# 22              Tiffany & Co.    237
# 23        The Walking Company    199
# ...

# %%
counts['Store_Category'] = counts.Store_Name.map(mapping)
counts
# Out:
#                    Store_Name  count           Store_Category
# 0         ProActiv Solutions   27629                    Misc.
# 1                   Swarovski  18719  Apparel and Accessories
# 2                   Cotton On  15505  Apparel And Accessories
# 3                     TAP 415  10520          Qsr Restaurants
# 4                Steve Madden   9611              Shoe Stores
# 5              Bloomingdale's   8855        Department Stores
# 6               Bristol Farms   3698       Casual Restaurants
# 7                     H&M Man   1467  Apparel And Accessories
# 8            49ers Team Store   1464            Sports Stores
# 9              Bespoke Events   1252                    Misc.
# 10                 M.Y. China    991          Qsr Restaurants
# 11          Club Monaco Women    977  Apparel And Accessories
# 12     L'Occitane en Provence    792      Furniture And Decor
# 13                     Camper    688              Shoe Stores
# ...

# %%
columns= ['Floor_name', 'Floor_Index']
for i in columns:
    newmapping = dict(storemap[['Store_Name',i]].values)
    counts[i] = counts.Store_Name.map(newmapping)

# %%
counts.to_csv(r"C:\Users\welcome\Desktop\EXL OUTPUTS\counts_ki_maka_bhosda.csv")
